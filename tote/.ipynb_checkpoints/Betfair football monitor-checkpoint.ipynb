# %% [markdown]
# # Betfair Football Monitor

# %%
import requests
import urllib
import json
import pandas as pd
import numpy as np
import pickle
from tqdm import tqdm_notebook
import datetime
import time
import importlib
import config
importlib.reload(config)
from config import username, password, application, dbpw
import logging

import matplotlib.pyplot as plt
import seaborn as sns

import pymysql
import sqlalchemy

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
pd.options.mode.chained_assignment = None

# %%
pd.options.display.max_columns = 100
pd.options.display.max_rows = 100

# %% [markdown]
# ## Get Results

# %% [markdown]
# #### Get bets from DB

# %%
connect_string = 'mysql+pymysql://root:'+dbpw+'@localhost/betfair'
sql_engine = sqlalchemy.create_engine(connect_string)
placed_bets = pd.read_sql('''
                        SELECT DISTINCT o.selection_id, o.market_id, o.side, o.bet_id
                        FROM football_order_results_live o
                        LEFT JOIN football_bet_outcomes_live b
                                    ON o.market_id = b.market_id
                                    AND o.selection_id = b.selection_id
                                    AND o.side = b.side
                                    AND o.bet_id = b.bet_id
                        WHERE order_status = 'EXECUTION_COMPLETE'
                        AND b.market_id IS NULL
                        
                        ''',
                      con=sql_engine)

# %%
len(placed_bets)
# Out:
# 6

# %%
placed_bets['bet_id'].nunique()
# Out:
# 6

# %% [markdown]
# #### Login to betfair

# %%
header = {'X-Application': application, 'Content-Type': 'application/x-www-form-urlencoded'}
auth = 'username='+username+'&password='+password

login = requests.post('https://identitysso-cert.betfair.com/api/certlogin',
                      cert=('/etc/ssl/client-2048.crt', '/etc/ssl/client-2048.key'),
                      headers=header, data=auth)

login_success = login.json()['loginStatus']
logging.info('Login '+str(login_success))

# %%
ssoid = login.json()['sessionToken']
headers = {'X-Application': application, 'X-Authentication': ssoid, 'content-type': 'application/json'}

# %% [markdown]
# #### Get bet outcomes

# %%
bet_url = "https://api.betfair.com/exchange/betting/json-rpc/v1"

# %%
markets = list(placed_bets['market_id'])
bet_outcomes = []
for m in markets:
    
    # get settled bets
    outcome_req = '{"jsonrpc": "2.0", "method": "SportsAPING/v1.0/listClearedOrders",\
                    "params": {"marketIds": ["' + str(m) + '"], "betStatus": "SETTLED"}, "id": 1}'
    request = requests.post(bet_url, data=outcome_req.encode('utf-8'), headers=headers)
    outcome_result = request.json()
    bet_outcomes += outcome_result['result']['clearedOrders']
    
    # get voided bets
    outcome_req = '{"jsonrpc": "2.0", "method": "SportsAPING/v1.0/listClearedOrders",\
                    "params": {"marketIds": ["' + str(m) + '"], "betStatus": "VOIDED"}, "id": 1}'
    request = requests.post(bet_url, data=outcome_req.encode('utf-8'), headers=headers)
    outcome_result = request.json()
    bet_outcomes += outcome_result['result']['clearedOrders']
    
#     # cancelled
#     outcome_req = '{"jsonrpc": "2.0", "method": "SportsAPING/v1.0/listClearedOrders",\
#                     "params": {"marketIds": ["' + str(m) + '"], "betStatus": "CANCELLED"}, "id": 1}'
#     request = requests.post(bet_url, data=outcome_req.encode('utf-8'), headers=headers)
#     outcome_result = request.json()
#     bet_outcomes += outcome_result['result']['clearedOrders']
    
#     # lapsed
#     outcome_req = '{"jsonrpc": "2.0", "method": "SportsAPING/v1.0/listClearedOrders",\
#                     "params": {"marketIds": ["' + str(m) + '"], "betStatus": "LAPSED"}, "id": 1}'
#     request = requests.post(bet_url, data=outcome_req.encode('utf-8'), headers=headers)
#     outcome_result = request.json()
#     bet_outcomes += outcome_result['result']['clearedOrders']

# %%
def parse_bet_outcome(bet_outcome):
    return [
        bet_outcome.get('eventTypeId', None),
        bet_outcome.get('eventId', None),
        bet_outcome.get('marketId', None),
        bet_outcome.get('selectionId', None),
        bet_outcome.get('handicap', None),
        bet_outcome.get('betId', None),
        bet_outcome.get('placedDate', None),
        bet_outcome.get('persistenceType', None),
        bet_outcome.get('orderType', None),
        bet_outcome.get('side', None),
        bet_outcome.get('betOutcome', None),
        bet_outcome.get('priceRequested', None),
        bet_outcome.get('settledDate', None),
        bet_outcome.get('lastMatchedDate', None),
        bet_outcome.get('betCount', None),
        bet_outcome.get('priceMatched', None),
        bet_outcome.get('priceReduced', None),
        bet_outcome.get('sizeSettled', None),
        bet_outcome.get('sizeCancelled', None),
        bet_outcome.get('profit', None),
    ]

outcome_cols = ['event_type_id', 'event_id', 'market_id', 'selection_id', 'handicap', 'bet_id', 'placed_date', 'persistence_type',
                'order_type', 'side', 'bet_outcome', 'price_requested', 'settled_date', 'last_matched_date', 'bet_count', 'price_matched',
                'price_reduced', 'size_settled', 'size_cancelled', 'profit']

# %%
bet_outcomes_df = pd.DataFrame([parse_bet_outcome(b) for b in bet_outcomes], columns=outcome_cols)

# %%
len(bet_outcomes_df)
# Out:
# 17

# %%
bet_outcomes_df.sort_values('bet_id')
# Out:
#    event_type_id  event_id    market_id  selection_id  handicap        bet_id  \
# 0              1  30635529  1.184654452         58805       0.0  236793698610
# 1              1  30635529  1.184654461             2       0.0  236793698996
# 5              1  30635529  1.184654461             2       0.0  236793698996
# 9              1  30635529  1.184654461             2       0.0  236793698996
# 13             1  30635529  1.184654461             2       0.0  236793698996
# 2              1  30635529  1.184654461             3       0.0  236800032600
# 14             1  30635529  1.184654461             3       0.0  236800032600
# 6              1  30635529  1.184654461             3       0.0  236800032600
# 10             1  30635529  1.184654461             3       0.0  236800032600
# 3              1  30635529  1.184654461             1       0.0  236824358450
# 7              1  30635529  1.184654461             1       0.0  236824358450
# 15             1  30635529  1.184654461             1       0.0  236824358450
# 11             1  30635529  1.184654461             1       0.0  236824358450
# 8              1  30635529  1.184654461             6       0.0  236824359558
# 4              1  30635529  1.184654461             6       0.0  236824359558
# 12             1  30635529  1.184654461             6       0.0  236824359558
# 16             1  30635529  1.184654461             6       0.0  236824359558
#
#                  placed_date persistence_type order_type  side bet_outcome  \
# 0   2021-06-26T11:51:34.000Z            LAPSE      LIMIT  BACK         WON
# 1   2021-06-26T11:51:35.000Z            LAPSE      LIMIT  BACK        LOST
# 5   2021-06-26T11:51:35.000Z            LAPSE      LIMIT  BACK        LOST
# 9   2021-06-26T11:51:35.000Z            LAPSE      LIMIT  BACK        LOST
# 13  2021-06-26T11:51:35.000Z            LAPSE      LIMIT  BACK        LOST
# 2   2021-06-26T12:56:49.000Z            LAPSE      LIMIT  BACK         WON
# 14  2021-06-26T12:56:49.000Z            LAPSE      LIMIT  BACK         WON
# 6   2021-06-26T12:56:49.000Z            LAPSE      LIMIT  BACK         WON
# 10  2021-06-26T12:56:49.000Z            LAPSE      LIMIT  BACK         WON
# 3   2021-06-26T16:11:53.000Z            LAPSE      LIMIT  BACK        LOST
# 7   2021-06-26T16:11:53.000Z            LAPSE      LIMIT  BACK        LOST
# 15  2021-06-26T16:11:53.000Z            LAPSE      LIMIT  BACK        LOST
# 11  2021-06-26T16:11:53.000Z            LAPSE      LIMIT  BACK        LOST
# 8   2021-06-26T16:11:53.000Z            LAPSE      LIMIT  BACK        LOST
# 4   2021-06-26T16:11:53.000Z            LAPSE      LIMIT  BACK        LOST
# 12  2021-06-26T16:11:53.000Z            LAPSE      LIMIT  BACK        LOST
# 16  2021-06-26T16:11:53.000Z            LAPSE      LIMIT  BACK        LOST
#
#     price_requested              settled_date         last_matched_date  \
# 0               5.2  2021-06-26T19:37:15.000Z  2021-06-26T11:51:34.000Z
# 1               6.6  2021-06-26T19:37:20.000Z  2021-06-26T11:51:35.000Z
# 5               6.6  2021-06-26T19:37:20.000Z  2021-06-26T11:51:35.000Z
# 9               6.6  2021-06-26T19:37:20.000Z  2021-06-26T11:51:35.000Z
# 13              6.6  2021-06-26T19:37:20.000Z  2021-06-26T11:51:35.000Z
# 2              11.0  2021-06-26T19:37:20.000Z  2021-06-26T12:56:49.000Z
# 14             11.0  2021-06-26T19:37:20.000Z  2021-06-26T12:56:49.000Z
# 6              11.0  2021-06-26T19:37:20.000Z  2021-06-26T12:56:49.000Z
# 10             11.0  2021-06-26T19:37:20.000Z  2021-06-26T12:56:49.000Z
# 3              14.0  2021-06-26T19:37:20.000Z  2021-06-26T16:11:53.000Z
# 7              14.0  2021-06-26T19:37:20.000Z  2021-06-26T16:11:53.000Z
# 15             14.0  2021-06-26T19:37:20.000Z  2021-06-26T16:11:53.000Z
# 11             14.0  2021-06-26T19:37:20.000Z  2021-06-26T16:11:53.000Z
# 8               9.6  2021-06-26T19:37:20.000Z  2021-06-26T16:11:53.000Z
# 4               9.6  2021-06-26T19:37:20.000Z  2021-06-26T16:11:53.000Z
# 12              9.6  2021-06-26T19:37:20.000Z  2021-06-26T16:11:53.000Z
# 16              9.6  2021-06-26T19:37:20.000Z  2021-06-26T16:11:53.000Z
#
#     bet_count  price_matched  price_reduced  size_settled size_cancelled  \
# 0           1            5.4          False           2.0           None
# 1           1            6.8          False           2.0           None
# 5           1            6.8          False           2.0           None
# 9           1            6.8          False           2.0           None
# 13          1            6.8          False           2.0           None
# 2           1           11.0          False           2.0           None
# 14          1           11.0          False           2.0           None
# 6           1           11.0          False           2.0           None
# 10          1           11.0          False           2.0           None
# 3           1           14.0          False           2.0           None
# 7           1           14.0          False           2.0           None
# 15          1           14.0          False           2.0           None
# 11          1           14.0          False           2.0           None
# 8           1           10.0          False           2.0           None
# 4           1           10.0          False           2.0           None
# 12          1           10.0          False           2.0           None
# 16          1           10.0          False           2.0           None
#
#     profit
# 0      8.8
# 1     -2.0
# 5     -2.0
# 9     -2.0
# 13    -2.0
# 2     20.0
# 14    20.0
# 6     20.0
# 10    20.0
# 3     -2.0
# 7     -2.0
# 15    -2.0
# 11    -2.0
# 8     -2.0
# 4     -2.0
# 12    -2.0
# 16    -2.0

# %%
bet_outcomes_df = bet_outcomes_df[bet_outcomes_df['bet_id'].isin(placed_bets['bet_id'])].groupby(['selection_id', 'market_id', 'bet_id']).head(1)

# %%
len(bet_outcomes_df)
# Out:
# 5

# %% [markdown]
# #### Send to DB

# %%
connect_string = 'mysql+pymysql://root:'+dbpw+'@localhost/betfair'
sql_engine = sqlalchemy.create_engine(connect_string)

# %%
bet_outcomes_df.to_sql(name='football_bet_outcomes_live', con=sql_engine, schema='betfair', if_exists='append', index=False)

# %% [markdown]
# ## Get all bets with results to monitor

# %%
connect_string = 'mysql+pymysql://root:'+dbpw+'@localhost/betfair'
sql_engine = sqlalchemy.create_engine(connect_string)
bet_outcomes_full = pd.read_sql('''
                                SELECT * FROM football_bet_outcomes_live
                                ''',
                                con=sql_engine)

# %%
# lay liab
bet_outcomes_full['liab'] = (bet_outcomes_full['price_matched']-1)*bet_outcomes_full['size_settled']

# back liab
bet_outcomes_full.loc[bet_outcomes_full['side']=='BACK', 'liab'] = bet_outcomes_full.loc[bet_outcomes_full['side']=='BACK', 'size_settled']

# void liab
bet_outcomes_full.loc[bet_outcomes_full['profit']==0, 'liab'] = 0

# %%
print(f"Total Bets: {sum(bet_outcomes_full['liab']!=0)}")
print(f"Total Liability: £{sum(bet_outcomes_full['liab'])}")
print(f"Total Return: £{round(sum(bet_outcomes_full['liab'] + bet_outcomes_full['profit']),2)}")
print(f"Total Profit: £{round(sum(bet_outcomes_full['profit']),2)}")
print(f"Profit Margin: {round(100*(sum(bet_outcomes_full['profit'])/sum(bet_outcomes_full['liab'])),2)}%")
# Out:
# Total Bets: 335
# Total Liability: £670.0
# Total Return: £690.38
# Total Profit: £20.38
# Profit Margin: 3.04%

# %% [markdown]
# ## Daily results

# %%
bet_outcomes_full['settled_day'] = pd.to_datetime(bet_outcomes_full['settled_date'], utc=True).dt.date

# %%
daily_aggs = bet_outcomes_full.groupby('settled_day')['liab', 'profit'].sum().reset_index().sort_values('settled_day')
daily_aggs['liab_cumulative'] = daily_aggs['liab'].cumsum()
daily_aggs['profit_cumulative'] = daily_aggs['profit'].cumsum()

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 7))

sns.lineplot(data=daily_aggs, x='settled_day', y='profit_cumulative', ax=ax, label='Cumulative Profit').set_title('Daily and Cumulative Profit')
sns.lineplot(data=daily_aggs, x='settled_day', y='profit', ax=ax, label='Daily Profit')
# Out:
# /home/angus/anaconda3/lib/python3.6/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Need to add in commission and add breakdowns

# %% [markdown]
# #### Statistical significance

# %%
connect_string = 'mysql+pymysql://root:'+dbpw+'@localhost/betfair'
sql_engine = sqlalchemy.create_engine(connect_string)
predictions_data = pd.read_sql('''
                        select * from
                            (
                            select b.*, o.market_start_time, o.api_call_time_utc, o.minutes_to_event,
                                    o.event_name, o.competition_name, o.market_name, o.market_type, o.country_code,
                                    o.timezone, o.total_matched_market, o.total_available, o.runner_name, o.ltp,
                                    o.back_price_1, o.back_price_2, o.back_price_3, o.back_size_1, o.back_size_2, o.back_size_3,
                                    o.lay_price_1, o.lay_price_2, o.lay_price_3, o.lay_size_1, o.lay_size_2, o.lay_size_3,
                                    o.runner_name_general, o.market_runner, o.input_odds, o.pred, o.pred_odds, o.bet,
                                    o.correct_score_overround, o.match_odds_overround, o.over_under_overround,
                                    ROW_NUMBER() OVER (PARTITION BY b.event_id, b.market_id, b.selection_id ORDER BY api_call_time_utc DESC) AS rn
                            from football_bet_outcomes_live b
                            left join football_output_live o on b.event_id = o.event_id
                                                            and b.market_id = o.market_id
                                                            and b.selection_id = o.runner_id
                                                            and o.api_call_time_utc <= b.placed_date
                            ) t
                        where rn = 1
                        ''',
                      con=sql_engine)
# Out:
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-01T07:20:59.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-01T07:21:00.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-01T21:18:03.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-01T21:18:04.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-01T21:18:06.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-04T15:42:29.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-22T16:05:41.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-25T13:30:50.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-03T07:24:03.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-17T10:36:43.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-18T13:09:02.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-21T16:25:48.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-02T15:17:09.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-05T10:43:57.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-18T14:31:28.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-12T22:06:35.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-16T08:39:10.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-12T15:00:08.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-16T22:45:47.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-19T18:10:49.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-03T13:39:18.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-25T11:22:27.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-02T15:17:11.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-02T15:17:10.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-12T09:49:29.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-12T09:49:30.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-25T15:40:21.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-13T12:19:53.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-23T09:31:15.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-19T14:59:35.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-21T13:51:09.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-25T10:50:36.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-03T13:39:19.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-09T17:13:25.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-18T15:37:59.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-12T17:24:14.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-19T15:41:21.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-05T06:25:03.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-05T06:25:06.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-19T08:48:32.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-25T11:22:26.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-05T06:25:04.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-26T11:51:33.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-04T07:06:25.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-18T10:41:31.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-21T13:20:18.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-16T11:47:51.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-25T11:54:18.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-25T13:30:51.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-12T15:03:09.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-17T12:58:16.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-23T09:31:16.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-08T14:45:51.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-13T13:51:38.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-19T17:46:23.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-03T13:39:17.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-08T14:45:52.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-24T11:54:19.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-25T21:56:40.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-16T15:56:22.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-20T13:03:45.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-14T09:45:59.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-20T13:03:46.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-22T09:49:32.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-15T05:58:34.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-03T07:24:04.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-03T07:24:05.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-11T16:38:24.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-24T13:27:48.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-22T15:02:36.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-24T12:56:35.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-19T22:03:01.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-25T21:56:39.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-26T13:29:43.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-13T14:47:05.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-18T09:51:02.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-23T12:44:30.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-03T13:39:15.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-25T10:50:37.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-25T12:58:32.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-15T07:27:53.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-05T06:25:05.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-24T07:14:22.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-02T15:17:08.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-03T20:49:22.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-12T15:00:09.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)

# %%
predictions_data['pred_bookie'] = 1/predictions_data['price_matched']

# %%
potential_winnings = 2*predictions_data['price_matched']
probs_me = predictions_data['pred']
probs_bookie_adj = predictions_data['pred_bookie']/1.03  # manual overround adjustment
samples = 10000
outcomes_me = [sum(np.random.binomial(1, probs_me)*potential_winnings)-len(probs_me)*2 for i in range(samples)]
outcomes_bookie = [sum(np.random.binomial(1, probs_bookie_adj)*potential_winnings)-len(probs_bookie_adj)*2 for i in range(samples)]

outcomes_me_adj = np.mean(outcomes_me) - (np.array(outcomes_me) - np.mean(outcomes_me))
outcomes_bookie_adj = np.mean(outcomes_bookie) - (np.array(outcomes_bookie) - np.mean(outcomes_bookie))

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 7))

sns.distplot(outcomes_me, ax=ax[0]).set_title('My Probs Outcome Dist')
ax[0].set(ylim=(0, None))
sns.distplot(outcomes_bookie, ax=ax[1]).set_title('Bookie Probs Outcome Dist')
ax[1].set(ylim=(0, None))
# Out:
# [(0, 0.0029587783801191593)]

# %%
sum(np.array(outcomes_me)<0)/len(outcomes_me)
# Out:
# 0.0232

# %%
sum(np.array(outcomes_bookie)<0)/len(outcomes_bookie)
# Out:
# 0.5726

# %%
sum(np.array(outcomes_me)>=sum(bet_outcomes_full['profit']))/len(outcomes_me)
# Out:
# 0.969

# %%
sum(np.array(outcomes_bookie)>=sum(bet_outcomes_full['profit']))/len(outcomes_bookie)
# Out:
# 0.3748

# %% [markdown]
# ## Check profitable areas

# %%
predictions_data['odds_pred_ratio'] = predictions_data['back_price_1']/predictions_data['pred_odds']
predictions_data['odds_pred_ratio_band'] = (predictions_data['odds_pred_ratio']*10).round()/10

# %%
predictions_data['pred_odds_band'] = (predictions_data['pred_odds']/5).round()*5
predictions_data['bookie_odds_band'] = (predictions_data['back_price_1']/5).round()*5

# %%
predictions_data.groupby('odds_pred_ratio_band').agg({
    'bet_id': len,
    'bet_outcome': lambda x: sum(np.array(x)=='WON'),
    'profit': sum
}).reset_index().sort_values('odds_pred_ratio_band')
# Out:
#     odds_pred_ratio_band  bet_id  bet_outcome  profit
# 0                    1.1       1            0   -2.00
# 1                    1.3     183           25  126.78
# 2                    1.4      56            4  -12.20
# 3                    1.5      30            2  -19.60
# 4                    1.6      24            2  -10.60
# 5                    1.7      16            0  -32.00
# 6                    1.8       9            0  -18.00
# 7                    1.9       7            1   10.00
# 8                    2.0       1            0   -2.00
# 9                    2.2       1            0   -2.00
# 10                   2.5       1            0   -2.00
# 11                   2.7       2            0   -4.00
# 12                   3.2       1            0   -2.00
# 13                   3.7       1            0   -2.00
# 14                   5.1       1            0   -2.00
# 15                   5.2       1            0   -2.00
# 16                   5.4       1            0   -2.00

# %%
predictions_data.groupby('pred_odds_band').agg({
    'bet_id': len,
    'bet_outcome': lambda x: sum(np.array(x)=='WON'),
    'profit': sum
}).reset_index().sort_values('pred_odds_band')
# Out:
#    pred_odds_band  bet_id  bet_outcome  profit
# 0             0.0       9            3   -5.52
# 1             5.0      90           16   22.90
# 2            10.0      81            8   17.00
# 3            15.0      79            6   80.00
# 4            20.0      65            0 -128.00
# 5            25.0      12            1   36.00

# %%
predictions_data.groupby('bookie_odds_band').agg({
    'bet_id': len,
    'bet_outcome': lambda x: sum(np.array(x)=='WON'),
    'profit': sum
}).reset_index().sort_values('bookie_odds_band')
# Out:
#    bookie_odds_band  bet_id  bet_outcome  profit
# 0               0.0       4            2   -1.00
# 1               5.0      52           13   31.58
# 2              10.0      69           11   85.80
# 3              15.0      49            2  -36.00
# 4              20.0      66            5   72.00
# 5              25.0      48            0  -94.00
# 6              30.0      48            1  -36.00

# %%
predictions_data.groupby('market_type').agg({
    'bet_id': len,
    'bet_outcome': lambda x: sum(np.array(x)=='WON'),
    'profit': sum
}).reset_index().sort_values('market_type')
# Out:
#      market_type  bet_id  bet_outcome  profit
# 0  CORRECT_SCORE     278           18  -46.20
# 1     MATCH_ODDS      41           13   90.10
# 2  OVER_UNDER_05      11            0  -22.00
# 3  OVER_UNDER_15       1            0   -2.00
# 4  OVER_UNDER_35       4            2   -1.00
# 5  OVER_UNDER_45       1            1    3.48

# %%
predictions_data.groupby('market_runner').agg({
    'bet_id': len,
    'bet_outcome': lambda x: sum(np.array(x)=='WON'),
    'profit': sum
}).reset_index().sort_values('market_runner')
# Out:
#                     market_runner  bet_id  bet_outcome  profit
# 0             CORRECT_SCORE 0 - 0      25            0  -50.00
# 1             CORRECT_SCORE 0 - 1       1            0   -2.00
# 2             CORRECT_SCORE 0 - 2      17            0  -34.00
# 3             CORRECT_SCORE 0 - 3       4            0   -8.00
# 4             CORRECT_SCORE 1 - 0       9            0  -18.00
# 5             CORRECT_SCORE 1 - 1      27            8  105.40
# 6             CORRECT_SCORE 1 - 2      21            1   -4.00
# 7             CORRECT_SCORE 1 - 3      11            1   18.00
# 8             CORRECT_SCORE 2 - 0       5            0  -10.00
# 9             CORRECT_SCORE 2 - 1      28            1  -32.00
# 10            CORRECT_SCORE 2 - 2      40            3   64.00
# 11            CORRECT_SCORE 2 - 3      28            1  -12.00
# 12            CORRECT_SCORE 3 - 0      10            2    6.40
# 13            CORRECT_SCORE 3 - 1      29            1  -24.00
# 14            CORRECT_SCORE 3 - 2      23            0  -46.00
# 15                MATCH_ODDS Away       1            1   26.00
# 16                MATCH_ODDS Home      14            3    9.69
# 17            MATCH_ODDS The Draw      26            9   54.41
# 18  OVER_UNDER_05 Under 0.5 Goals      11            0  -22.00
# 19  OVER_UNDER_15 Under 1.5 Goals       1            0   -2.00
# 20   OVER_UNDER_35 Over 3.5 Goals       2            1   -0.48
# 21  OVER_UNDER_35 Under 3.5 Goals       2            1   -0.52
# 22   OVER_UNDER_45 Over 4.5 Goals       1            1    3.48

# %%
predictions_data.groupby('competition_name').agg({
    'bet_id': len,
    'bet_outcome': lambda x: sum(np.array(x)=='WON'),
    'profit': sum
}).reset_index().sort_values('competition_name')
# Out:
#                     competition_name  bet_id  bet_outcome  profit
# 0               AFC Champions League      12            0  -24.00
# 1     Argentinian Primera B Nacional       3            0   -6.00
# 2          Argentinian Superliga Cup       1            0   -2.00
# 3                Australian A-League       2            0   -4.00
# 4            Belarusian 1st Division       2            0   -4.00
# 5          Belarusian Premier League      17            3   36.80
# 6                      Brazilian Cup      13            0  -26.00
# 7                  Brazilian Serie A       8            6  128.40
# 8                  Brazilian Serie B      22            0  -40.00
# 9          CONCACAF Nations League A       1            0   -2.00
# 10             CONMEBOL Copa America      25            1  -46.52
# 11           Estonian Premier League       2            0   -4.00
# 12         FIFA World Cup Qualifiers      38            4   -9.20
# 13             Finnish Veikkausliiga       4            0   -8.00
# 14          Friendlies International      34            3    4.00
# 15            Georgian Umaglesi Liga       2            0   -4.00
# 16                 Icelandic 1 Deild      38            4    7.00
# 17             Icelandic Urvalsdeild       8            1   -8.20
# 18                  Irish Division 1      14            0  -28.00
# 19            Irish Premier Division      13            4   36.41
# 20                 Japanese J League       1            0   -2.00
# 21               Japanese J League 2       4            1    6.40
# 22             Moroccan Botola Pro 1       2            0   -4.00
# 23             Norwegian Eliteserien       9            1  -10.11
# 24                  Romanian Matches       1            0   -2.00
# 25          Spanish Segunda Division       3            1   30.00
# 26                       Swedish Cup       1            0   -2.00
# 27  UEFA Champions League Qualifiers       6            0  -12.00
# 28                    UEFA Euro 2020      32            3   -8.60
# 29          UEFA U21 Euro Qualifiers       4            0   -8.00
# 30            US Major League Soccer       5            0  -10.00
# 31                 US USL League One       2            1   18.00
# 32           US United Soccer League       7            1   30.00

# %% [markdown]
# #### View all

# %%
pd.options.display.max_columns = 100
pd.options.display.max_rows = 120

# %%
predictions_data[[
    'placed_date', 'bet_outcome', 'settled_date', 'price_matched', 'profit', 'market_start_time', 'api_call_time_utc',
    'minutes_to_event', 'event_name', 'competition_name', 'market_name', 'market_type', 'country_code', 'timezone', 'total_matched_market',
    'total_available', 'runner_name', 'ltp', 'back_price_1', 'back_price_2',
    'back_price_3', 'back_size_1', 'back_size_2', 'back_size_3',
       'lay_price_1', 'lay_price_2', 'lay_price_3', 'lay_size_1', 'lay_size_2',
       'lay_size_3', 'runner_name_general', 'market_runner', 'input_odds',
       'pred', 'pred_odds', 'bet', 'correct_score_overround',
       'match_odds_overround', 'over_under_overround', 'rn', 'pred_bookie',
       'odds_pred_ratio', 'odds_pred_ratio_band', 'pred_odds_band',
       'bookie_odds_band']]
# Out:
#                   placed_date bet_outcome              settled_date  \
# 0    2021-06-12T15:00:09.000Z         WON  2021-06-12T19:30:52.000Z
# 1    2021-06-12T15:03:09.000Z        LOST  2021-06-12T19:31:23.000Z
# 2    2021-06-12T15:03:10.000Z        LOST  2021-06-12T19:31:23.000Z
# 3    2021-06-16T11:47:51.000Z        LOST  2021-06-16T14:59:56.000Z
# 4    2021-06-16T11:47:51.000Z        LOST  2021-06-16T14:59:56.000Z
# ..                        ...         ...                       ...
# 331  2021-06-26T07:31:30.000Z        LOST  2021-06-26T15:49:35.000Z
# 332  2021-06-26T11:51:34.000Z        LOST  2021-06-26T15:49:40.000Z
# 333  2021-06-26T12:56:49.000Z        LOST  2021-06-26T15:49:40.000Z
# 334  2021-06-26T11:51:34.000Z        LOST  2021-06-26T15:49:40.000Z
# 335  2021-06-26T11:51:33.000Z         WON  2021-06-26T15:49:40.000Z
#
#      price_matched  profit         market_start_time   api_call_time_utc  \
# 0            14.00    26.0  2021-06-12T16:00:00.000Z 2021-06-12 14:58:26
# 1             5.80    -2.0  2021-06-12T16:00:00.000Z 2021-06-12 15:01:22
# 2            19.00    -2.0  2021-06-12T16:00:00.000Z 2021-06-12 15:01:22
# 3             9.20    -2.0  2021-06-16T13:00:00.000Z 2021-06-16 11:44:42
# 4            27.00    -2.0  2021-06-16T13:00:00.000Z 2021-06-16 11:44:42
# ..             ...     ...                       ...                 ...
# 331           2.76    -2.0  2021-06-26T14:00:00.000Z 2021-06-26 07:30:18
# 332          22.00    -2.0  2021-06-26T14:00:00.000Z 2021-06-26 11:50:23
# 333          22.00    -2.0  2021-06-26T14:00:00.000Z 2021-06-26 12:55:37
# 334          23.00    -2.0  2021-06-26T14:00:00.000Z 2021-06-26 11:50:23
# 335          20.00    38.0  2021-06-26T14:00:00.000Z 2021-06-26 11:50:23
#
#      minutes_to_event              event_name   competition_name  \
# 0           61.566667       Denmark v Finland     UEFA Euro 2020
# 1           58.633333       Denmark v Finland     UEFA Euro 2020
# 2           58.633333       Denmark v Finland     UEFA Euro 2020
# 3           75.300000        Finland v Russia     UEFA Euro 2020
# 4           75.300000        Finland v Russia     UEFA Euro 2020
# ..                ...                     ...                ...
# 331        389.700000  Throttur v Afturelding  Icelandic 1 Deild
# 332        129.616667  Throttur v Afturelding  Icelandic 1 Deild
# 333         64.383333  Throttur v Afturelding  Icelandic 1 Deild
# 334        129.616667  Throttur v Afturelding  Icelandic 1 Deild
# 335        129.616667  Throttur v Afturelding  Icelandic 1 Deild
#
#        market_name    market_type country_code timezone  total_matched_market  \
# 0       Match Odds     MATCH_ODDS         None      GMT            1661245.44
# 1    Correct Score  CORRECT_SCORE         None      GMT             290615.03
# 2    Correct Score  CORRECT_SCORE         None      GMT             290615.03
# 3    Correct Score  CORRECT_SCORE         None      GMT             176081.94
# 4    Correct Score  CORRECT_SCORE         None      GMT             176081.94
# ..             ...            ...          ...      ...                   ...
# 331     Match Odds     MATCH_ODDS           IS      GMT                336.83
# 332  Correct Score  CORRECT_SCORE           IS      GMT                153.69
# 333  Correct Score  CORRECT_SCORE           IS      GMT                422.63
# 334  Correct Score  CORRECT_SCORE           IS      GMT                153.69
# 335  Correct Score  CORRECT_SCORE           IS      GMT                153.69
#
#      total_available runner_name    ltp  back_price_1  back_price_2  \
# 0         1466187.57     Finland  14.00         13.50          13.0
# 1         1359141.68       1 - 0   5.80          5.80           5.7
# 2         1359141.68       3 - 1  18.50         18.50          18.0
# 3         1475161.20       1 - 1   9.40          9.20           9.0
# 4         1475161.20       2 - 1  27.00         27.00          26.0
# ..               ...         ...    ...           ...           ...
# 331          2040.45    Throttur   2.74          2.72           2.7
# 332         49568.87       3 - 1    NaN         22.00          21.0
# 333         52003.77       3 - 2  23.00         22.00          21.0
# 334         49568.87       2 - 3    NaN         23.00          21.0
# 335         49568.87       1 - 3    NaN         20.00          19.5
#
#      back_price_3  back_size_1  back_size_2  back_size_3  lay_price_1  \
# 0           12.50      2234.39      2436.18      3464.34        14.50
# 1            5.60       540.86      1433.83      1493.76         5.90
# 2           17.50      1421.34       829.58       361.23        19.00
# 3            8.80       159.97      1020.32       435.73         9.60
# 4           25.00       193.71       150.46        44.02        28.00
# ..            ...          ...          ...          ...          ...
# 331          2.68        13.77        14.67        30.16         2.92
# 332         20.00        15.90        13.70        13.93        24.00
# 333         20.00        51.04        10.56        16.06        24.00
# 334         12.50        41.91        15.50        12.37        25.00
# 335         19.00        39.81        18.90        13.83        22.00
#
#      lay_price_2  lay_price_3  lay_size_1  lay_size_2  lay_size_3  \
# 0          15.00        15.50      546.84     2268.94     3771.57
# 1           6.00         6.20      810.35     1071.49     1613.59
# 2          19.50        20.00      203.18      854.01     1279.89
# 3           9.80        10.00     4255.70      249.85       31.02
# 4          29.00        30.00      998.30       31.31      105.01
# ..           ...          ...         ...         ...         ...
# 331         2.94         2.96       73.92       50.99       21.01
# 332        25.00       380.00       10.42       11.18       10.11
# 333        25.00       160.00       10.70       16.00        6.47
# 334        27.00        29.00       12.18       30.38        3.54
# 335        24.00       180.00       46.60       13.12        3.31
#
#     runner_name_general        market_runner  input_odds      pred  pred_odds  \
# 0                  Away      MATCH_ODDS Away       13.50  0.111498   8.968789
# 1                 1 - 0  CORRECT_SCORE 1 - 0        5.80  0.225859   4.427535
# 2                 3 - 1  CORRECT_SCORE 3 - 1       18.50  0.103708   9.642480
# 3                 1 - 1  CORRECT_SCORE 1 - 1        9.20  0.138985   7.195026
# 4                 2 - 1  CORRECT_SCORE 2 - 1       27.00  0.046321  21.588655
# ..                  ...                  ...         ...       ...        ...
# 331                Home      MATCH_ODDS Home        2.72  0.460510   2.171507
# 332               3 - 1  CORRECT_SCORE 3 - 1       22.00  0.057695  17.332591
# 333               3 - 2  CORRECT_SCORE 3 - 2       22.00  0.078035  12.814768
# 334               2 - 3  CORRECT_SCORE 2 - 3       23.00  0.072802  13.735875
# 335               1 - 3  CORRECT_SCORE 1 - 3       20.00  0.064033  15.616965
#
#      bet  correct_score_overround  match_odds_overround  over_under_overround  \
# 0      1                 0.886220              1.009022              5.036725
# 1      1                 0.890976              1.005528              5.025461
# 2      1                 0.890976              1.005528              5.025461
# 3      1                 0.949564              1.002419              5.027455
# 4      1                 0.949564              1.002419              5.027455
# ..   ...                      ...                   ...                   ...
# 331    1                 0.883048              1.031718              6.176978
# 332    1                 0.847042              1.008498              5.176074
# 333    1                 0.824755              1.013999              5.150514
# 334    1                 0.847042              1.008498              5.176074
# 335    1                 0.847042              1.008498              5.176074
#
#      rn  pred_bookie  odds_pred_ratio  odds_pred_ratio_band  pred_odds_band  \
# 0     1     0.071429         1.505220                   1.5            10.0
# 1     1     0.172414         1.309984                   1.3             5.0
# 2     1     0.052632         1.918594                   1.9            10.0
# 3     1     0.108696         1.278661                   1.3             5.0
# 4     1     0.037037         1.250657                   1.3            20.0
# ..   ..          ...              ...                   ...             ...
# 331   1     0.362319         1.252586                   1.3             0.0
# 332   1     0.045455         1.269285                   1.3            15.0
# 333   1     0.045455         1.716769                   1.7            15.0
# 334   1     0.043478         1.674447                   1.7            15.0
# 335   1     0.050000         1.280659                   1.3            15.0
#
#      bookie_odds_band
# 0                15.0
# 1                 5.0
# 2                20.0
# 3                10.0
# 4                25.0
# ..                ...
# 331               5.0
# 332              20.0
# 333              20.0
# 334              25.0
# 335              20.0
#
# [336 rows x 45 columns]

# %%
predictions_data.groupby('market_type').agg({
    'total_matched_market': [lambda x: np.quantile(x, 0.05),
                             lambda x: np.quantile(x, 0.15),
                             lambda x: np.quantile(x, 0.25),
                             lambda x: np.quantile(x, 0.5),
                             lambda x: np.quantile(x, 0.75),
                             lambda x: np.quantile(x, 0.85),
                             lambda x: np.quantile(x, 0.95)]
})
# Out:
#               total_matched_market                                   \
#                         <lambda_0> <lambda_1> <lambda_2> <lambda_3>
# market_type
# CORRECT_SCORE                0.000     20.220    113.180    556.000
# MATCH_ODDS                 238.970    513.030    917.870   2980.050
# OVER_UNDER_05                7.910     49.750    334.840   1014.880
# OVER_UNDER_15              933.910    933.910    933.910    933.910
# OVER_UNDER_35               60.713    114.299    167.885    682.685
# OVER_UNDER_45              101.820    101.820    101.820    101.820
#
#
#                <lambda_4>  <lambda_5>   <lambda_6>
# market_type
# CORRECT_SCORE   2470.2525    6515.096   52585.3075
# MATCH_ODDS     16644.8800  110998.160  876803.1700
# OVER_UNDER_05   3025.2800    6507.175   14503.9800
# OVER_UNDER_15    933.9100     933.910     933.9100
# OVER_UNDER_35   1165.9550    1181.705    1197.4550
# OVER_UNDER_45    101.8200     101.820     101.8200

# %%
predictions_data['low_total_matched'] = 0
predictions_data.loc[(predictions_data['market_type']=='CORRECT_SCORE') & (predictions_data['total_matched_market']<1000), 'low_total_matched'] = 1
predictions_data.loc[(predictions_data['market_type']=='MATCH_ODDS') & (predictions_data['total_matched_market']<5000), 'low_total_matched'] = 1
predictions_data.loc[(predictions_data['market_type']=='OVER_UNDER_05') & (predictions_data['total_matched_market']<1000), 'low_total_matched'] = 1
predictions_data.loc[(predictions_data['market_type']=='OVER_UNDER_35') & (predictions_data['total_matched_market']<1000), 'low_total_matched'] = 1

# %%
predictions_data.groupby('low_total_matched').agg({
    'bet_id': len,
    'bet_outcome': lambda x: sum(np.array(x)=='WON'),
    'profit': sum
}).reset_index().sort_values('low_total_matched')
# Out:
#    low_total_matched  bet_id  bet_outcome  profit
# 0                  0     133           12  -44.84
# 1                  1     203           22   67.22

# %%
predictions_data.groupby(['low_total_matched', 'market_type']).agg({
    'bet_id': len,
    'bet_outcome': lambda x: sum(np.array(x)=='WON'),
    'profit': sum
}).reset_index().sort_values(['market_type', 'low_total_matched'])
# Out:
#    low_total_matched    market_type  bet_id  bet_outcome  profit
# 0                  0  CORRECT_SCORE     105            5  -75.60
# 6                  1  CORRECT_SCORE     173           13   29.40
# 1                  0     MATCH_ODDS      18            5   41.80
# 7                  1     MATCH_ODDS      23            8   48.30
# 2                  0  OVER_UNDER_05       6            0  -12.00
# 8                  1  OVER_UNDER_05       5            0  -10.00
# 3                  0  OVER_UNDER_15       1            0   -2.00
# 4                  0  OVER_UNDER_35       2            1   -0.52
# 9                  1  OVER_UNDER_35       2            1   -0.48
# 5                  0  OVER_UNDER_45       1            1    3.48

# %%
predictions_data['minutes_to_event'].describe()
# Out:
# count     336.000000
# mean      345.486706
# std       240.713727
# min         0.716667
# 25%       175.950000
# 50%       322.850000
# 75%       500.325000
# max      1311.116667
# Name: minutes_to_event, dtype: float64

# %%
predictions_data['long_before'] = (predictions_data['minutes_to_event']>240)*1
predictions_data.groupby(['long_before', 'market_type']).agg({
    'bet_id': len,
    'bet_outcome': lambda x: sum(np.array(x)=='WON'),
    'profit': sum
}).reset_index().sort_values(['market_type', 'long_before'])
# Out:
#    long_before    market_type  bet_id  bet_outcome  profit
# 0            0  CORRECT_SCORE      96            3  -93.00
# 5            1  CORRECT_SCORE     182           15   46.80
# 1            0     MATCH_ODDS      12            3   19.69
# 6            1     MATCH_ODDS      29           10   70.41
# 2            0  OVER_UNDER_05       6            0  -12.00
# 7            1  OVER_UNDER_05       5            0  -10.00
# 3            0  OVER_UNDER_15       1            0   -2.00
# 4            0  OVER_UNDER_35       1            0   -2.00
# 8            1  OVER_UNDER_35       3            2    1.00
# 9            1  OVER_UNDER_45       1            1    3.48

# %%
predictions_data['lay_back_gap'] = predictions_data['lay_price_1'] - predictions_data['back_price_1']
predictions_data['lay_back_gap_pc'] = predictions_data['lay_back_gap']/predictions_data['back_price_1']

# %%
predictions_data.loc[predictions_data['lay_back_gap'].isnull(), 'lay_back_gap'] = 999
predictions_data.loc[predictions_data['lay_back_gap_pc'].isnull(), 'lay_back_gap_pc'] = 999

# %%
predictions_data['lay_back_gap_pc'].describe()
# Out:
# count    336.000000
# mean      29.919064
# std      169.980554
# min        0.016949
# 25%        0.066304
# 50%        0.090909
# 75%        0.180668
# max      999.000000
# Name: lay_back_gap_pc, dtype: float64

# %%
predictions_data['big_lay_back_gap_pc'] = (predictions_data['lay_back_gap_pc']>0.1)*1
predictions_data.groupby(['big_lay_back_gap_pc']).agg({
    'bet_id': len,
    'bet_outcome': lambda x: sum(np.array(x)=='WON'),
    'profit': sum
}).reset_index().sort_values('big_lay_back_gap_pc')
# Out:
#    big_lay_back_gap_pc  bet_id  bet_outcome  profit
# 0                    0     202           25  111.41
# 1                    1     134            9  -89.03

# %%
predictions_data.groupby(['big_lay_back_gap_pc', 'market_type']).agg({
    'bet_id': len,
    'bet_outcome': lambda x: sum(np.array(x)=='WON'),
    'profit': sum
}).reset_index().sort_values(['market_type', 'big_lay_back_gap_pc'])
# Out:
#    big_lay_back_gap_pc    market_type  bet_id  bet_outcome  profit
# 0                    0  CORRECT_SCORE     162           14   61.80
# 5                    1  CORRECT_SCORE     116            4 -108.00
# 1                    0     MATCH_ODDS      33            9   56.61
# 6                    1     MATCH_ODDS       8            4   33.49
# 2                    0  OVER_UNDER_05       2            0   -4.00
# 7                    1  OVER_UNDER_05       9            0  -18.00
# 3                    0  OVER_UNDER_15       1            0   -2.00
# 4                    0  OVER_UNDER_35       4            2   -1.00
# 8                    1  OVER_UNDER_45       1            1    3.48

# %%
predictions_data.groupby(['big_lay_back_gap_pc', 'long_before']).agg({
    'bet_id': len,
    'bet_outcome': lambda x: sum(np.array(x)=='WON'),
    'profit': sum
}).reset_index().sort_values(['big_lay_back_gap_pc', 'long_before'])
# Out:
#    big_lay_back_gap_pc  long_before  bet_id  bet_outcome  profit
# 0                    0            0      78            5  -21.20
# 1                    0            1     124           20  132.61
# 2                    1            0      38            1  -68.11
# 3                    1            1      96            8  -20.92

# %%
predictions_data.groupby(['big_lay_back_gap_pc', 'long_before', 'low_total_matched']).agg({
    'bet_id': len,
    'bet_outcome': lambda x: sum(np.array(x)=='WON'),
    'profit': sum
}).reset_index().sort_values(['big_lay_back_gap_pc', 'long_before', 'low_total_matched'])
# Out:
#    big_lay_back_gap_pc  long_before  low_total_matched  bet_id  bet_outcome  \
# 0                    0            0                  0      51            1
# 1                    0            0                  1      27            4
# 2                    0            1                  0      65           10
# 3                    0            1                  1      59           10
# 4                    1            0                  0       6            0
# 5                    1            0                  1      32            1
# 6                    1            1                  0      11            1
# 7                    1            1                  1      85            7
#
#    profit
# 0  -74.00
# 1   52.80
# 2   57.68
# 3   74.93
# 4  -12.00
# 5  -56.11
# 6  -16.52
# 7   -4.40

# %%
predictions_data.groupby(['big_lay_back_gap_pc', 'long_before', 'market_type']).agg({
    'bet_id': len,
    'bet_outcome': lambda x: sum(np.array(x)=='WON'),
    'profit': sum
}).reset_index().sort_values(['big_lay_back_gap_pc', 'long_before', 'market_type'])
# Out:
#     big_lay_back_gap_pc  long_before    market_type  bet_id  bet_outcome  \
# 0                     0            0  CORRECT_SCORE      63            3
# 1                     0            0     MATCH_ODDS      11            2
# 2                     0            0  OVER_UNDER_05       2            0
# 3                     0            0  OVER_UNDER_15       1            0
# 4                     0            0  OVER_UNDER_35       1            0
# 5                     0            1  CORRECT_SCORE      99           11
# 6                     0            1     MATCH_ODDS      22            7
# 7                     0            1  OVER_UNDER_35       3            2
# 8                     1            0  CORRECT_SCORE      33            0
# 9                     1            0     MATCH_ODDS       1            1
# 10                    1            0  OVER_UNDER_05       4            0
# 11                    1            1  CORRECT_SCORE      83            4
# 12                    1            1     MATCH_ODDS       7            3
# 13                    1            1  OVER_UNDER_05       5            0
# 14                    1            1  OVER_UNDER_45       1            1
#
#     profit
# 0   -27.00
# 1    13.80
# 2    -4.00
# 3    -2.00
# 4    -2.00
# 5    88.80
# 6    42.81
# 7     1.00
# 8   -66.00
# 9     5.89
# 10   -8.00
# 11  -42.00
# 12   27.60
# 13  -10.00
# 14    3.48

# %% [markdown]
# #### Is it bad to do too many bets on same event?

# %%
event_bets = predictions_data.groupby('event_id').size().reset_index().rename(columns={0: 'event_total_bets'})
predictions_data_with_event_counts = predictions_data.merge(event_bets, how='left', on='event_id')

# %%
predictions_data_with_event_counts.groupby(['event_total_bets']).agg({
    'bet_id': len,
    'bet_outcome': lambda x: sum(np.array(x)=='WON'),
    'profit': sum
}).reset_index().sort_values(['event_total_bets'])
# Out:
#    event_total_bets  bet_id  bet_outcome  profit
# 0                 1     103            8   55.40
# 1                 2      74            8   -1.91
# 2                 3      48           11   51.81
# 3                 4      60            3  -57.20
# 4                 5      20            4   36.28
# 5                 6      24            0  -48.00
# 6                 7       7            0  -14.00

# %% [markdown]
# #### Split data in half to check for consistency of breakdown

# %%
split_date = pd.to_datetime('2021-06-17', utc=True) # nb: strategy changed on 21/06/2021 to exclude high lay_back_gap_pc for correct_score bets
predictions_data_with_event_counts['period'] = (pd.to_datetime(predictions_data_with_event_counts['market_start_time']) > split_date)*1

# %%
predictions_data_with_event_counts.groupby('period').size()
# Out:
# period
# 0    165
# 1    171
# dtype: int64

# %%
predictions_data_with_event_counts.groupby(['period', 'market_type']).agg({
    'bet_id': len,
    'bet_outcome': lambda x: sum(np.array(x)=='WON'),
    'profit': sum
}).reset_index().sort_values(['period', 'market_type'])
# Out:
#    period    market_type  bet_id  bet_outcome  profit
# 0       0  CORRECT_SCORE     137            9  -37.60
# 1       0     MATCH_ODDS      16            8   78.29
# 2       0  OVER_UNDER_05       8            0  -16.00
# 3       0  OVER_UNDER_35       3            2    1.00
# 4       0  OVER_UNDER_45       1            1    3.48
# 5       1  CORRECT_SCORE     141            9   -8.60
# 6       1     MATCH_ODDS      25            5   11.81
# 7       1  OVER_UNDER_05       3            0   -6.00
# 8       1  OVER_UNDER_15       1            0   -2.00
# 9       1  OVER_UNDER_35       1            0   -2.00

# %%
predictions_data_with_event_counts.groupby(['period', 'big_lay_back_gap_pc', 'long_before', 'market_type']).agg({
    'bet_id': len,
    'bet_outcome': lambda x: sum(np.array(x)=='WON'),
    'profit': sum
}).reset_index().sort_values(['period', 'big_lay_back_gap_pc', 'long_before', 'market_type'])
# Out:
#     period  big_lay_back_gap_pc  long_before    market_type  bet_id  \
# 0        0                    0            0  CORRECT_SCORE      27
# 1        0                    0            0     MATCH_ODDS       5
# 2        0                    0            0  OVER_UNDER_05       2
# 3        0                    0            0  OVER_UNDER_35       1
# 4        0                    0            1  CORRECT_SCORE      35
# 5        0                    0            1     MATCH_ODDS       8
# 6        0                    0            1  OVER_UNDER_35       2
# 7        0                    1            0  CORRECT_SCORE      23
# 8        0                    1            0     MATCH_ODDS       1
# 9        0                    1            0  OVER_UNDER_05       3
# 10       0                    1            1  CORRECT_SCORE      52
# 11       0                    1            1     MATCH_ODDS       2
# 12       0                    1            1  OVER_UNDER_05       3
# 13       0                    1            1  OVER_UNDER_45       1
# 14       1                    0            0  CORRECT_SCORE      36
# 15       1                    0            0     MATCH_ODDS       6
# 16       1                    0            0  OVER_UNDER_15       1
# 17       1                    0            1  CORRECT_SCORE      64
# 18       1                    0            1     MATCH_ODDS      14
# 19       1                    0            1  OVER_UNDER_35       1
# 20       1                    1            0  CORRECT_SCORE      10
# 21       1                    1            0  OVER_UNDER_05       1
# 22       1                    1            1  CORRECT_SCORE      31
# 23       1                    1            1     MATCH_ODDS       5
# 24       1                    1            1  OVER_UNDER_05       2
#
#     bet_outcome  profit
# 0             1  -33.00
# 1             2   25.80
# 2             0   -4.00
# 3             0   -2.00
# 4             5   57.40
# 5             3   19.80
# 6             2    3.00
# 7             0  -46.00
# 8             1    5.89
# 9             0   -6.00
# 10            3  -16.00
# 11            2   26.80
# 12            0   -6.00
# 13            1    3.48
# 14            2    6.00
# 15            0  -12.00
# 16            0   -2.00
# 17            6   31.40
# 18            4   23.01
# 19            0   -2.00
# 20            0  -20.00
# 21            0   -2.00
# 22            1  -26.00
# 23            1    0.80
# 24            0   -4.00

# %%
predictions_data_with_event_counts.groupby(['period', 'big_lay_back_gap_pc', 'long_before', 'low_total_matched']).agg({
    'bet_id': len,
    'bet_outcome': lambda x: sum(np.array(x)=='WON'),
    'profit': sum
}).reset_index().sort_values(['period', 'big_lay_back_gap_pc', 'long_before', 'low_total_matched'])
# Out:
#     period  big_lay_back_gap_pc  long_before  low_total_matched  bet_id  \
# 0        0                    0            0                  0      27
# 1        0                    0            0                  1       8
# 2        0                    0            1                  0      26
# 3        0                    0            1                  1      19
# 4        0                    1            0                  0       4
# 5        0                    1            0                  1      23
# 6        0                    1            1                  0       9
# 7        0                    1            1                  1      49
# 8        1                    0            0                  0      24
# 9        1                    0            0                  1      19
# 10       1                    0            1                  0      39
# 11       1                    0            1                  1      40
# 12       1                    1            0                  0       2
# 13       1                    1            0                  1       9
# 14       1                    1            1                  0       2
# 15       1                    1            1                  1      36
#
#     bet_outcome  profit
# 0             1  -26.00
# 1             2   12.80
# 2             5    5.08
# 3             5   75.12
# 4             0   -8.00
# 5             1  -38.11
# 6             1  -12.52
# 7             5   20.80
# 8             0  -48.00
# 9             2   40.00
# 10            5   52.60
# 11            5   -0.19
# 12            0   -4.00
# 13            0  -18.00
# 14            0   -4.00
# 15            2  -25.20

# %%
predictions_data_with_event_counts.groupby(['period', 'big_lay_back_gap_pc', 'long_before']).agg({
    'bet_id': len,
    'bet_outcome': lambda x: sum(np.array(x)=='WON'),
    'profit': sum
}).reset_index().sort_values(['period', 'big_lay_back_gap_pc', 'long_before'])
# Out:
#    period  big_lay_back_gap_pc  long_before  bet_id  bet_outcome  profit
# 0       0                    0            0      35            3  -13.20
# 1       0                    0            1      45           10   80.20
# 2       0                    1            0      27            1  -46.11
# 3       0                    1            1      58            6    8.28
# 4       1                    0            0      43            2   -8.00
# 5       1                    0            1      79           10   52.41
# 6       1                    1            0      11            0  -22.00
# 7       1                    1            1      38            2  -29.20

# %%
predictions_data_with_event_counts['low_odds'] = (predictions_data_with_event_counts['back_price_1']<20)*1

# %%
predictions_data_with_event_counts.groupby(['period', 'low_odds']).agg({
    'bet_id': len,
    'bet_outcome': lambda x: sum(np.array(x)=='WON'),
    'profit': sum
}).reset_index().sort_values(['period', 'low_odds'])
# Out:
#    period  low_odds  bet_id  bet_outcome  profit
# 0       0         0      66            2  -44.00
# 1       0         1      99           18   73.17
# 2       1         0      72            2  -40.00
# 3       1         1      99           12   33.21

# %%
predictions_data_with_event_counts.groupby(['period', 'low_odds', 'market_type']).agg({
    'bet_id': len,
    'bet_outcome': lambda x: sum(np.array(x)=='WON'),
    'profit': sum
}).reset_index().sort_values(['period', 'low_odds', 'market_type'])
# Out:
#     period  low_odds    market_type  bet_id  bet_outcome  profit
# 0        0         0  CORRECT_SCORE      62            2  -36.00
# 1        0         0  OVER_UNDER_05       4            0   -8.00
# 2        0         1  CORRECT_SCORE      75            7   -1.60
# 3        0         1     MATCH_ODDS      16            8   78.29
# 4        0         1  OVER_UNDER_05       4            0   -8.00
# 5        0         1  OVER_UNDER_35       3            2    1.00
# 6        0         1  OVER_UNDER_45       1            1    3.48
# 7        1         0  CORRECT_SCORE      71            2  -38.00
# 8        1         0  OVER_UNDER_05       1            0   -2.00
# 9        1         1  CORRECT_SCORE      70            7   29.40
# 10       1         1     MATCH_ODDS      25            5   11.81
# 11       1         1  OVER_UNDER_05       2            0   -4.00
# 12       1         1  OVER_UNDER_15       1            0   -2.00
# 13       1         1  OVER_UNDER_35       1            0   -2.00

# %%
predictions_data_with_event_counts.groupby(['period', 'big_lay_back_gap_pc', 'long_before', 'low_odds']).agg({
    'bet_id': len,
    'bet_outcome': lambda x: sum(np.array(x)=='WON'),
    'profit': sum
}).reset_index().sort_values(['period', 'big_lay_back_gap_pc', 'long_before', 'low_odds'])
# Out:
#     period  big_lay_back_gap_pc  long_before  low_odds  bet_id  bet_outcome  \
# 0        0                    0            0         0      10            0
# 1        0                    0            0         1      25            3
# 2        0                    0            1         0      13            1
# 3        0                    0            1         1      32            9
# 4        0                    1            0         0       8            0
# 5        0                    1            0         1      19            1
# 6        0                    1            1         0      35            1
# 7        0                    1            1         1      23            5
# 8        1                    0            0         0      15            1
# 9        1                    0            0         1      28            1
# 10       1                    0            1         0      25            1
# 11       1                    0            1         1      54            9
# 12       1                    1            0         0       9            0
# 13       1                    1            0         1       2            0
# 14       1                    1            1         0      23            0
# 15       1                    1            1         1      15            2
#
#     profit
# 0   -20.00
# 1     6.80
# 2    18.00
# 3    62.20
# 4   -16.00
# 5   -30.11
# 6   -26.00
# 7    34.28
# 8    10.00
# 9   -18.00
# 10   12.00
# 11   40.41
# 12  -18.00
# 13   -4.00
# 14  -44.00
# 15   14.80
