# %% [markdown]
# # Betfair Football Monitor

# %%
import requests
import urllib
import json
import pandas as pd
import numpy as np
import pickle
from tqdm import tqdm_notebook
import datetime
import time
import importlib
import config
importlib.reload(config)
from config import username, password, application, dbpw
import logging

import matplotlib.pyplot as plt
import seaborn as sns

import pymysql
import sqlalchemy

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
pd.options.mode.chained_assignment = None

# %%
pd.options.display.max_columns = 100
pd.options.display.max_rows = 100

# %% [markdown]
# ## Get Results

# %% [markdown]
# #### Get bets from DB

# %%
connect_string = 'mysql+pymysql://root:'+dbpw+'@localhost/betfair'
sql_engine = sqlalchemy.create_engine(connect_string)
placed_bets = pd.read_sql('''
                        SELECT DISTINCT o.selection_id, o.market_id, o.side, o.bet_id
                        FROM football_order_results_live o
                        LEFT JOIN football_bet_outcomes_live b
                                    ON o.market_id = b.market_id
                                    AND o.selection_id = b.selection_id
                                    AND o.side = b.side
                                    AND o.bet_id = b.bet_id
                        WHERE order_status = 'EXECUTION_COMPLETE'
                        AND b.market_id IS NULL
                        
                        ''',
                      con=sql_engine)

# %%
len(placed_bets)
# Out:
# 8

# %%
placed_bets['bet_id'].nunique()
# Out:
# 8

# %% [markdown]
# #### Login to betfair

# %%
header = {'X-Application': application, 'Content-Type': 'application/x-www-form-urlencoded'}
auth = 'username='+username+'&password='+password

login = requests.post('https://identitysso-cert.betfair.com/api/certlogin',
                      cert=('/etc/ssl/client-2048.crt', '/etc/ssl/client-2048.key'),
                      headers=header, data=auth)

login_success = login.json()['loginStatus']
logging.info('Login '+str(login_success))

# %%
ssoid = login.json()['sessionToken']
headers = {'X-Application': application, 'X-Authentication': ssoid, 'content-type': 'application/json'}

# %% [markdown]
# #### Get bet outcomes

# %%
bet_url = "https://api.betfair.com/exchange/betting/json-rpc/v1"

# %%
markets = list(placed_bets['market_id'])
bet_outcomes = []
for m in markets:
    
    # get settled bets
    outcome_req = '{"jsonrpc": "2.0", "method": "SportsAPING/v1.0/listClearedOrders",\
                    "params": {"marketIds": ["' + str(m) + '"], "betStatus": "SETTLED"}, "id": 1}'
    request = requests.post(bet_url, data=outcome_req.encode('utf-8'), headers=headers)
    outcome_result = request.json()
    bet_outcomes += outcome_result['result']['clearedOrders']
    
    # get voided bets
    outcome_req = '{"jsonrpc": "2.0", "method": "SportsAPING/v1.0/listClearedOrders",\
                    "params": {"marketIds": ["' + str(m) + '"], "betStatus": "VOIDED"}, "id": 1}'
    request = requests.post(bet_url, data=outcome_req.encode('utf-8'), headers=headers)
    outcome_result = request.json()
    bet_outcomes += outcome_result['result']['clearedOrders']
    
#     # cancelled
#     outcome_req = '{"jsonrpc": "2.0", "method": "SportsAPING/v1.0/listClearedOrders",\
#                     "params": {"marketIds": ["' + str(m) + '"], "betStatus": "CANCELLED"}, "id": 1}'
#     request = requests.post(bet_url, data=outcome_req.encode('utf-8'), headers=headers)
#     outcome_result = request.json()
#     bet_outcomes += outcome_result['result']['clearedOrders']
    
#     # lapsed
#     outcome_req = '{"jsonrpc": "2.0", "method": "SportsAPING/v1.0/listClearedOrders",\
#                     "params": {"marketIds": ["' + str(m) + '"], "betStatus": "LAPSED"}, "id": 1}'
#     request = requests.post(bet_url, data=outcome_req.encode('utf-8'), headers=headers)
#     outcome_result = request.json()
#     bet_outcomes += outcome_result['result']['clearedOrders']

# %%
def parse_bet_outcome(bet_outcome):
    return [
        bet_outcome.get('eventTypeId', None),
        bet_outcome.get('eventId', None),
        bet_outcome.get('marketId', None),
        bet_outcome.get('selectionId', None),
        bet_outcome.get('handicap', None),
        bet_outcome.get('betId', None),
        bet_outcome.get('placedDate', None),
        bet_outcome.get('persistenceType', None),
        bet_outcome.get('orderType', None),
        bet_outcome.get('side', None),
        bet_outcome.get('betOutcome', None),
        bet_outcome.get('priceRequested', None),
        bet_outcome.get('settledDate', None),
        bet_outcome.get('lastMatchedDate', None),
        bet_outcome.get('betCount', None),
        bet_outcome.get('priceMatched', None),
        bet_outcome.get('priceReduced', None),
        bet_outcome.get('sizeSettled', None),
        bet_outcome.get('sizeCancelled', None),
        bet_outcome.get('profit', None),
    ]

outcome_cols = ['event_type_id', 'event_id', 'market_id', 'selection_id', 'handicap', 'bet_id', 'placed_date', 'persistence_type',
                'order_type', 'side', 'bet_outcome', 'price_requested', 'settled_date', 'last_matched_date', 'bet_count', 'price_matched',
                'price_reduced', 'size_settled', 'size_cancelled', 'profit']

# %%
bet_outcomes_df = pd.DataFrame([parse_bet_outcome(b) for b in bet_outcomes], columns=outcome_cols)

# %%
len(bet_outcomes_df)
# Out:
# 19

# %%
bet_outcomes_df.sort_values('bet_id')
# Out:
#    event_type_id  event_id    market_id  selection_id  handicap        bet_id  \
# 0              1  30533040  1.183514575             3       0.0  236088922225
# 1              1  30584764  1.184115231             1       0.0  236097590417
# 15             1  30584764  1.184115231             1       0.0  236097590417
# 5              1  30584764  1.184115231             1       0.0  236097590417
# 11             1  30584764  1.184115231             1       0.0  236097590417
# 2              1  30584764  1.184115231             6       0.0  236097591380
# 16             1  30584764  1.184115231             6       0.0  236097591380
# 6              1  30584764  1.184115231             6       0.0  236097591380
# 12             1  30584764  1.184115231             6       0.0  236097591380
# 9              1  30584764  1.184115227       5851482       0.0  236097592078
# 10             1  30584764  1.184115222         58805       0.0  236112544255
# 7              1  30584764  1.184115231             3       0.0  236112544685
# 13             1  30584764  1.184115231             3       0.0  236112544685
# 3              1  30584764  1.184115231             3       0.0  236112544685
# 17             1  30584764  1.184115231             3       0.0  236112544685
# 8              1  30584764  1.184115231            11       0.0  236128929796
# 14             1  30584764  1.184115231            11       0.0  236128929796
# 4              1  30584764  1.184115231            11       0.0  236128929796
# 18             1  30584764  1.184115231            11       0.0  236128929796
#
#                  placed_date persistence_type order_type  side bet_outcome  \
# 0   2021-06-17T12:58:16.000Z            LAPSE      LIMIT  BACK        LOST
# 1   2021-06-17T14:54:20.000Z            LAPSE      LIMIT  BACK        LOST
# 15  2021-06-17T14:54:20.000Z            LAPSE      LIMIT  BACK        LOST
# 5   2021-06-17T14:54:20.000Z            LAPSE      LIMIT  BACK        LOST
# 11  2021-06-17T14:54:20.000Z            LAPSE      LIMIT  BACK        LOST
# 2   2021-06-17T14:54:20.000Z            LAPSE      LIMIT  BACK        LOST
# 16  2021-06-17T14:54:20.000Z            LAPSE      LIMIT  BACK        LOST
# 6   2021-06-17T14:54:20.000Z            LAPSE      LIMIT  BACK        LOST
# 12  2021-06-17T14:54:20.000Z            LAPSE      LIMIT  BACK        LOST
# 9   2021-06-17T14:54:21.000Z            LAPSE      LIMIT  BACK        LOST
# 10  2021-06-17T17:33:38.000Z            LAPSE      LIMIT  BACK        LOST
# 7   2021-06-17T17:33:38.000Z            LAPSE      LIMIT  BACK        LOST
# 13  2021-06-17T17:33:38.000Z            LAPSE      LIMIT  BACK        LOST
# 3   2021-06-17T17:33:38.000Z            LAPSE      LIMIT  BACK        LOST
# 17  2021-06-17T17:33:38.000Z            LAPSE      LIMIT  BACK        LOST
# 8   2021-06-17T22:27:55.000Z            LAPSE      LIMIT  BACK        LOST
# 14  2021-06-17T22:27:55.000Z            LAPSE      LIMIT  BACK        LOST
# 4   2021-06-17T22:27:55.000Z            LAPSE      LIMIT  BACK        LOST
# 18  2021-06-17T22:27:55.000Z            LAPSE      LIMIT  BACK        LOST
#
#     price_requested              settled_date         last_matched_date  \
# 0              10.5  2021-06-17T22:59:53.000Z  2021-06-17T12:58:16.000Z
# 1              20.0  2021-06-18T01:56:12.000Z  2021-06-17T14:54:20.000Z
# 15             20.0  2021-06-18T01:56:12.000Z  2021-06-17T14:54:20.000Z
# 5              20.0  2021-06-18T01:56:12.000Z  2021-06-17T14:54:20.000Z
# 11             20.0  2021-06-18T01:56:12.000Z  2021-06-17T14:54:20.000Z
# 2              11.5  2021-06-18T01:56:12.000Z  2021-06-17T14:54:20.000Z
# 16             11.5  2021-06-18T01:56:12.000Z  2021-06-17T14:54:20.000Z
# 6              11.5  2021-06-18T01:56:12.000Z  2021-06-17T14:54:20.000Z
# 12             11.5  2021-06-18T01:56:12.000Z  2021-06-17T14:54:20.000Z
# 9              21.0  2021-06-18T00:13:21.000Z  2021-06-17T14:54:21.000Z
# 10              7.6  2021-06-18T01:56:11.000Z  2021-06-17T17:33:38.000Z
# 7              16.5  2021-06-18T01:56:12.000Z  2021-06-17T17:33:38.000Z
# 13             16.5  2021-06-18T01:56:12.000Z  2021-06-17T17:33:38.000Z
# 3              16.5  2021-06-18T01:56:12.000Z  2021-06-17T17:33:38.000Z
# 17             16.5  2021-06-18T01:56:12.000Z  2021-06-17T17:33:38.000Z
# 8              15.5  2021-06-18T01:56:12.000Z  2021-06-17T22:27:55.000Z
# 14             15.5  2021-06-18T01:56:12.000Z  2021-06-17T22:27:55.000Z
# 4              15.5  2021-06-18T01:56:12.000Z  2021-06-17T22:27:55.000Z
# 18             15.5  2021-06-18T01:56:12.000Z  2021-06-17T22:27:55.000Z
#
#     bet_count  price_matched  price_reduced  size_settled size_cancelled  \
# 0           1           10.5          False           2.0           None
# 1           1           20.0          False           2.0           None
# 15          1           20.0          False           2.0           None
# 5           1           20.0          False           2.0           None
# 11          1           20.0          False           2.0           None
# 2           1           11.5          False           2.0           None
# 16          1           11.5          False           2.0           None
# 6           1           11.5          False           2.0           None
# 12          1           11.5          False           2.0           None
# 9           1           21.0          False           2.0           None
# 10          1            7.6          False           2.0           None
# 7           1           16.5          False           2.0           None
# 13          1           16.5          False           2.0           None
# 3           1           16.5          False           2.0           None
# 17          1           16.5          False           2.0           None
# 8           1           15.5          False           2.0           None
# 14          1           15.5          False           2.0           None
# 4           1           15.5          False           2.0           None
# 18          1           15.5          False           2.0           None
#
#     profit
# 0     -2.0
# 1     -2.0
# 15    -2.0
# 5     -2.0
# 11    -2.0
# 2     -2.0
# 16    -2.0
# 6     -2.0
# 12    -2.0
# 9     -2.0
# 10    -2.0
# 7     -2.0
# 13    -2.0
# 3     -2.0
# 17    -2.0
# 8     -2.0
# 14    -2.0
# 4     -2.0
# 18    -2.0

# %%
bet_outcomes_df = bet_outcomes_df[bet_outcomes_df['bet_id'].isin(placed_bets['bet_id'])].groupby(['selection_id', 'market_id', 'bet_id']).head(1)

# %%
len(bet_outcomes_df)
# Out:
# 7

# %% [markdown]
# #### Send to DB

# %%
connect_string = 'mysql+pymysql://root:'+dbpw+'@localhost/betfair'
sql_engine = sqlalchemy.create_engine(connect_string)

# %%
bet_outcomes_df.to_sql(name='football_bet_outcomes_live', con=sql_engine, schema='betfair', if_exists='append', index=False)

# %% [markdown]
# ## Get all bets with results to monitor

# %%
connect_string = 'mysql+pymysql://root:'+dbpw+'@localhost/betfair'
sql_engine = sqlalchemy.create_engine(connect_string)
bet_outcomes_full = pd.read_sql('''
                                SELECT * FROM football_bet_outcomes_live
                                ''',
                                con=sql_engine)

# %%
# lay liab
bet_outcomes_full['liab'] = (bet_outcomes_full['price_matched']-1)*bet_outcomes_full['size_settled']

# back liab
bet_outcomes_full.loc[bet_outcomes_full['side']=='BACK', 'liab'] = bet_outcomes_full.loc[bet_outcomes_full['side']=='BACK', 'size_settled']

# void liab
bet_outcomes_full.loc[bet_outcomes_full['profit']==0, 'liab'] = 0

# %%
print(f"Total Bets: {sum(bet_outcomes_full['liab']!=0)}")
print(f"Total Liability: £{sum(bet_outcomes_full['liab'])}")
print(f"Total Return: £{round(sum(bet_outcomes_full['liab'] + bet_outcomes_full['profit']),2)}")
print(f"Total Profit: £{round(sum(bet_outcomes_full['profit']),2)}")
print(f"Profit Margin: {round(100*(sum(bet_outcomes_full['profit'])/sum(bet_outcomes_full['liab'])),2)}%")
# Out:
# Total Bets: 183
# Total Liability: £366.0
# Total Return: £397.17
# Total Profit: £31.17
# Profit Margin: 8.52%

# %% [markdown]
# ## Daily results

# %%
bet_outcomes_full['settled_day'] = pd.to_datetime(bet_outcomes_full['settled_date'], utc=True).dt.date

# %%
daily_aggs = bet_outcomes_full.groupby('settled_day')['liab', 'profit'].sum().reset_index().sort_values('settled_day')
daily_aggs['liab_cumulative'] = daily_aggs['liab'].cumsum()
daily_aggs['profit_cumulative'] = daily_aggs['profit'].cumsum()

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 7))

sns.lineplot(data=daily_aggs, x='settled_day', y='profit_cumulative', ax=ax, label='Cumulative Profit').set_title('Daily and Cumulative Profit')
sns.lineplot(data=daily_aggs, x='settled_day', y='profit', ax=ax, label='Daily Profit')
# Out:
# /home/angus/anaconda3/lib/python3.6/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Need to add in commission and add breakdowns

# %% [markdown]
# #### Statistical significance

# %%
connect_string = 'mysql+pymysql://root:'+dbpw+'@localhost/betfair'
sql_engine = sqlalchemy.create_engine(connect_string)
predictions_data = pd.read_sql('''
                        select * from
                            (
                            select b.*, o.market_start_time, o.api_call_time_utc, o.minutes_to_event,
                                    o.event_name, o.competition_name, o.market_name, o.market_type, o.country_code,
                                    o.timezone, o.total_matched_market, o.total_available, o.runner_name, o.ltp,
                                    o.back_price_1, o.back_price_2, o.back_price_3, o.back_size_1, o.back_size_2, o.back_size_3,
                                    o.lay_price_1, o.lay_price_2, o.lay_price_3, o.lay_size_1, o.lay_size_2, o.lay_size_3,
                                    o.runner_name_general, o.market_runner, o.input_odds, o.pred, o.pred_odds, o.bet,
                                    o.correct_score_overround, o.match_odds_overround, o.over_under_overround,
                                    ROW_NUMBER() OVER (PARTITION BY b.event_id, b.market_id, b.selection_id ORDER BY api_call_time_utc DESC) AS rn
                            from football_bet_outcomes_live b
                            left join football_output_live o on b.event_id = o.event_id
                                                            and b.market_id = o.market_id
                                                            and b.selection_id = o.runner_id
                                                            and o.api_call_time_utc <= b.placed_date
                            ) t
                        where rn = 1
                        ''',
                      con=sql_engine)
# Out:
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-01T07:20:59.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-01T07:21:00.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-01T21:18:03.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-01T21:18:04.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-01T21:18:06.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-04T15:42:29.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-03T07:24:03.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-17T10:36:43.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-02T15:17:09.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-05T10:43:57.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-12T22:06:35.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-16T08:39:10.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-12T15:00:08.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-16T22:45:47.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-03T13:39:18.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-02T15:17:11.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-02T15:17:10.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-12T09:49:29.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-12T09:49:30.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-13T12:19:53.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-03T13:39:19.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-09T17:13:25.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-12T17:24:14.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-05T06:25:03.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-05T06:25:06.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-05T06:25:04.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-04T07:06:25.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-16T11:47:51.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-12T15:03:09.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-17T12:58:16.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-08T14:45:51.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-13T13:51:38.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-03T13:39:17.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-08T14:45:52.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-16T15:56:22.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-14T09:45:59.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-15T05:58:34.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-03T07:24:04.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-03T07:24:05.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-11T16:38:24.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-13T14:47:05.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-03T13:39:15.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-15T07:27:53.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-05T06:25:05.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-02T15:17:08.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-03T20:49:22.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-12T15:00:09.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-12T15:03:10.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-14T19:17:27.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-03T13:39:21.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-03T13:39:16.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-04T13:06:50.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-11T17:41:54.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-17T22:27:55.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-08T14:45:50.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-09T17:13:26.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-14T20:59:21.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-15T09:36:41.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-16T15:31:25.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-05T10:43:58.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-04T22:29:17.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-01T21:18:05.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-04T13:06:49.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-16T07:41:43.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-17T17:33:37.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-02T15:17:12.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-09T17:13:27.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-13T14:47:04.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-04T22:29:16.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-04T07:06:26.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-15T09:36:42.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-15T12:59:42.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-15T09:38:36.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-13T13:51:37.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-17T14:54:20.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-17T17:33:38.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-16T11:47:50.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-16T20:15:13.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-14T06:35:37.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-12T17:27:10.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-17T14:54:21.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-15T06:49:14.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-05T10:43:56.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-09T08:53:30.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-16T15:56:23.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-17T06:54:37.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-09T17:13:28.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-14T15:14:26.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-15T17:20:02.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-14T09:46:00.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-04T15:42:30.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-13T12:19:54.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-03T13:39:20.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-16T11:30:31.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-17T13:39:30.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-04T22:29:15.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-14T15:14:25.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)
# /home/angus/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1292, "Incorrect datetime value: '2021-06-15T20:09:47.000Z' for column 'api_call_time_utc' at row 1")
#   result = self._query(query)

# %%
predictions_data['pred_bookie'] = 1/predictions_data['price_matched']

# %%
potential_winnings = 2*predictions_data['price_matched']
probs_me = predictions_data['pred']
probs_bookie_adj = predictions_data['pred_bookie']/1.03  # manual overround adjustment
samples = 10000
outcomes_me = [sum(np.random.binomial(1, probs_me)*potential_winnings)-len(probs_me)*2 for i in range(samples)]
outcomes_bookie = [sum(np.random.binomial(1, probs_bookie_adj)*potential_winnings)-len(probs_bookie_adj)*2 for i in range(samples)]

outcomes_me_adj = np.mean(outcomes_me) - (np.array(outcomes_me) - np.mean(outcomes_me))
outcomes_bookie_adj = np.mean(outcomes_bookie) - (np.array(outcomes_bookie) - np.mean(outcomes_bookie))

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 7))

sns.distplot(outcomes_me, ax=ax[0]).set_title('My Probs Outcome Dist')
ax[0].set(ylim=(0, None))
sns.distplot(outcomes_bookie, ax=ax[1]).set_title('Bookie Probs Outcome Dist')
ax[1].set(ylim=(0, None))
# Out:
# [(0, 0.004065500252652857)]

# %%
sum(np.array(outcomes_me)<0)/len(outcomes_me)
# Out:
# 0.0546

# %%
sum(np.array(outcomes_bookie)<0)/len(outcomes_bookie)
# Out:
# 0.5685

# %%
sum(np.array(outcomes_me)>=sum(bet_outcomes_full['profit']))/len(outcomes_me)
# Out:
# 0.9134

# %%
sum(np.array(outcomes_bookie)>=sum(bet_outcomes_full['profit']))/len(outcomes_bookie)
# Out:
# 0.3313

# %% [markdown]
# ## Check profitable areas

# %%
predictions_data['odds_pred_ratio'] = predictions_data['back_price_1']/predictions_data['pred_odds']
predictions_data['odds_pred_ratio_band'] = (predictions_data['odds_pred_ratio']*10).round()/10

# %%
predictions_data['pred_odds_band'] = (predictions_data['pred_odds']/5).round()*5
predictions_data['bookie_odds_band'] = (predictions_data['back_price_1']/5).round()*5

# %%
predictions_data.groupby('odds_pred_ratio_band').agg({
    'bet_id': len,
    'bet_outcome': lambda x: sum(np.array(x)=='WON'),
    'profit': sum
}).reset_index().sort_values('odds_pred_ratio_band')
# Out:
#     odds_pred_ratio_band  bet_id  bet_outcome  profit
# 0                    1.3      96           16   75.77
# 1                    1.4      28            2    9.00
# 2                    1.5      15            1   -2.00
# 3                    1.6      15            1  -17.60
# 4                    1.7       9            0  -18.00
# 5                    1.8       7            0  -14.00
# 6                    1.9       5            1   14.00
# 7                    2.5       1            0   -2.00
# 8                    2.7       2            0   -4.00
# 9                    3.7       1            0   -2.00
# 10                   5.1       1            0   -2.00
# 11                   5.2       1            0   -2.00
# 12                   5.4       1            0   -2.00

# %%
predictions_data.groupby('pred_odds_band').agg({
    'bet_id': len,
    'bet_outcome': lambda x: sum(np.array(x)=='WON'),
    'profit': sum
}).reset_index().sort_values('pred_odds_band')
# Out:
#    pred_odds_band  bet_id  bet_outcome  profit
# 0             0.0       5            3    2.48
# 1             5.0      50            9   10.69
# 2            10.0      52            5    8.00
# 3            15.0      35            4   92.00
# 4            20.0      36            0  -72.00
# 5            25.0       4            0   -8.00

# %%
predictions_data.groupby('bookie_odds_band').agg({
    'bet_id': len,
    'bet_outcome': lambda x: sum(np.array(x)=='WON'),
    'profit': sum
}).reset_index().sort_values('bookie_odds_band')
# Out:
#    bookie_odds_band  bet_id  bet_outcome  profit
# 0               0.0       3            2    1.00
# 1               5.0      27            8   22.57
# 2              10.0      42            6   39.60
# 3              15.0      28            1  -28.00
# 4              20.0      32            4   98.00
# 5              25.0      23            0  -46.00
# 6              30.0      27            0  -54.00

# %%
predictions_data.groupby('market_type').agg({
    'bet_id': len,
    'bet_outcome': lambda x: sum(np.array(x)=='WON'),
    'profit': sum
}).reset_index().sort_values('market_type')
# Out:
#      market_type  bet_id  bet_outcome  profit
# 0  CORRECT_SCORE     151           10  -27.60
# 1     MATCH_ODDS      18            8   74.29
# 2  OVER_UNDER_05       9            0  -18.00
# 3  OVER_UNDER_35       3            2    1.00
# 4  OVER_UNDER_45       1            1    3.48

# %%
predictions_data.groupby('market_runner').agg({
    'bet_id': len,
    'bet_outcome': lambda x: sum(np.array(x)=='WON'),
    'profit': sum
}).reset_index().sort_values('market_runner')
# Out:
#                     market_runner  bet_id  bet_outcome  profit
# 0             CORRECT_SCORE 0 - 0       9            0  -18.00
# 1             CORRECT_SCORE 0 - 2       9            0  -18.00
# 2             CORRECT_SCORE 0 - 3       2            0   -4.00
# 3             CORRECT_SCORE 1 - 0       6            0  -12.00
# 4             CORRECT_SCORE 1 - 1      15            3   32.00
# 5             CORRECT_SCORE 1 - 2       8            1   20.00
# 6             CORRECT_SCORE 1 - 3       3            0   -6.00
# 7             CORRECT_SCORE 2 - 0       4            0   -8.00
# 8             CORRECT_SCORE 2 - 1      18            1  -12.00
# 9             CORRECT_SCORE 2 - 2      22            2   38.00
# 10            CORRECT_SCORE 2 - 3      16            1   12.00
# 11            CORRECT_SCORE 3 - 0       4            2   18.40
# 12            CORRECT_SCORE 3 - 1      21            0  -42.00
# 13            CORRECT_SCORE 3 - 2      14            0  -28.00
# 14                MATCH_ODDS Away       1            1   26.00
# 15                MATCH_ODDS Home       5            3   27.69
# 16            MATCH_ODDS The Draw      12            4   20.60
# 17  OVER_UNDER_05 Under 0.5 Goals       9            0  -18.00
# 18   OVER_UNDER_35 Over 3.5 Goals       1            1    1.52
# 19  OVER_UNDER_35 Under 3.5 Goals       2            1   -0.52
# 20   OVER_UNDER_45 Over 4.5 Goals       1            1    3.48

# %%
predictions_data.groupby('competition_name').agg({
    'bet_id': len,
    'bet_outcome': lambda x: sum(np.array(x)=='WON'),
    'profit': sum
}).reset_index().sort_values('competition_name')
# Out:
#                   competition_name  bet_id  bet_outcome  profit
# 0   Argentinian Primera B Nacional       2            0   -4.00
# 1        Argentinian Superliga Cup       1            0   -2.00
# 2              Australian A-League       2            0   -4.00
# 3          Belarusian 1st Division       2            0   -4.00
# 4        Belarusian Premier League       7            1   24.00
# 5                    Brazilian Cup      13            0  -26.00
# 6                Brazilian Serie A       3            2   25.00
# 7                Brazilian Serie B       7            0  -14.00
# 8        CONCACAF Nations League A       1            0   -2.00
# 9            CONMEBOL Copa America      15            1  -26.52
# 10       FIFA World Cup Qualifiers      38            4   -9.20
# 11           Finnish Veikkausliiga       1            0   -2.00
# 12        Friendlies International      34            3    4.00
# 13               Icelandic 1 Deild      12            2  -15.00
# 14           Icelandic Urvalsdeild       5            1   -2.20
# 15                Irish Division 1       3            0   -6.00
# 16          Irish Premier Division       1            1   19.00
# 17             Japanese J League 2       2            0   -4.00
# 18           Moroccan Botola Pro 1       2            0   -4.00
# 19           Norwegian Eliteserien       5            1   -2.11
# 20                Romanian Matches       1            0   -2.00
# 21        Spanish Segunda Division       3            1   30.00
# 22                     Swedish Cup       1            0   -2.00
# 23                  UEFA Euro 2020       8            2   22.20
# 24        UEFA U21 Euro Qualifiers       4            0   -8.00
# 25               US USL League One       2            1   18.00
# 26         US United Soccer League       7            1   30.00

# %% [markdown]
# #### View all

# %%
pd.options.display.max_columns = 100
pd.options.display.max_rows = 120

# %%
predictions_data[[
    'placed_date', 'bet_outcome', 'settled_date', 'price_matched', 'profit', 'market_start_time', 'api_call_time_utc',
    'minutes_to_event', 'event_name', 'competition_name', 'market_name', 'market_type', 'country_code', 'timezone', 'total_matched_market',
    'total_available', 'runner_name', 'ltp', 'back_price_1', 'back_price_2',
    'back_price_3', 'back_size_1', 'back_size_2', 'back_size_3',
       'lay_price_1', 'lay_price_2', 'lay_price_3', 'lay_size_1', 'lay_size_2',
       'lay_size_3', 'runner_name_general', 'market_runner', 'input_odds',
       'pred', 'pred_odds', 'bet', 'correct_score_overround',
       'match_odds_overround', 'over_under_overround', 'rn', 'pred_bookie',
       'odds_pred_ratio', 'odds_pred_ratio_band', 'pred_odds_band',
       'bookie_odds_band']]
# Out:
#                   placed_date bet_outcome              settled_date  \
# 0    2021-06-12T15:00:09.000Z         WON  2021-06-12T19:30:52.000Z
# 1    2021-06-12T15:03:09.000Z        LOST  2021-06-12T19:31:23.000Z
# 2    2021-06-12T15:03:10.000Z        LOST  2021-06-12T19:31:23.000Z
# 3    2021-06-16T11:47:51.000Z        LOST  2021-06-16T14:59:56.000Z
# 4    2021-06-16T11:47:51.000Z        LOST  2021-06-16T14:59:56.000Z
# ..                        ...         ...                       ...
# 177  2021-06-16T20:15:13.000Z        LOST  2021-06-17T02:23:50.000Z
# 178  2021-06-16T20:15:13.000Z        LOST  2021-06-17T02:24:22.000Z
# 179  2021-06-16T20:15:13.000Z        LOST  2021-06-17T02:24:22.000Z
# 180  2021-06-16T15:56:23.000Z        LOST  2021-06-17T02:24:22.000Z
# 181  2021-06-17T17:33:37.000Z        LOST  2021-06-17T20:58:24.000Z
#
#      price_matched  profit         market_start_time   api_call_time_utc  \
# 0             14.0    26.0  2021-06-12T16:00:00.000Z 2021-06-12 14:58:26
# 1              5.8    -2.0  2021-06-12T16:00:00.000Z 2021-06-12 15:01:22
# 2             19.0    -2.0  2021-06-12T16:00:00.000Z 2021-06-12 15:01:22
# 3              9.2    -2.0  2021-06-16T13:00:00.000Z 2021-06-16 11:44:42
# 4             27.0    -2.0  2021-06-16T13:00:00.000Z 2021-06-16 11:44:42
# ..             ...     ...                       ...                 ...
# 177            5.7    -2.0  2021-06-17T00:30:00.000Z 2021-06-16 20:13:16
# 178            6.4    -2.0  2021-06-17T00:30:00.000Z 2021-06-16 20:13:16
# 179           12.0    -2.0  2021-06-17T00:30:00.000Z 2021-06-16 20:13:16
# 180           16.0    -2.0  2021-06-17T00:30:00.000Z 2021-06-16 15:54:42
# 181           22.0    -2.0  2021-06-17T19:00:00.000Z 2021-06-17 17:32:34
#
#      minutes_to_event           event_name   competition_name    market_name  \
# 0           61.566667    Denmark v Finland     UEFA Euro 2020     Match Odds
# 1           58.633333    Denmark v Finland     UEFA Euro 2020  Correct Score
# 2           58.633333    Denmark v Finland     UEFA Euro 2020  Correct Score
# 3           75.300000     Finland v Russia     UEFA Euro 2020  Correct Score
# 4           75.300000     Finland v Russia     UEFA Euro 2020  Correct Score
# ..                ...                  ...                ...            ...
# 177        256.716667  Flamengo v Coritiba      Brazilian Cup     Match Odds
# 178        256.716667  Flamengo v Coritiba      Brazilian Cup  Correct Score
# 179        256.716667  Flamengo v Coritiba      Brazilian Cup  Correct Score
# 180        515.300000  Flamengo v Coritiba      Brazilian Cup  Correct Score
# 181         87.433333  America MG v Cuiaba  Brazilian Serie A  Correct Score
#
#        market_type country_code timezone  total_matched_market  \
# 0       MATCH_ODDS         None      GMT            1661245.44
# 1    CORRECT_SCORE         None      GMT             290615.03
# 2    CORRECT_SCORE         None      GMT             290615.03
# 3    CORRECT_SCORE         None      GMT             176081.94
# 4    CORRECT_SCORE         None      GMT             176081.94
# ..             ...          ...      ...                   ...
# 177     MATCH_ODDS           BR      GMT               2671.34
# 178  CORRECT_SCORE           BR      GMT               1015.00
# 179  CORRECT_SCORE           BR      GMT               1015.00
# 180  CORRECT_SCORE           BR      GMT                537.88
# 181  CORRECT_SCORE           BR      GMT                832.99
#
#      total_available runner_name   ltp  back_price_1  back_price_2  \
# 0         1466187.57     Finland  14.0          13.5          13.0
# 1         1359141.68       1 - 0   5.8           5.8           5.7
# 2         1359141.68       3 - 1  18.5          18.5          18.0
# 3         1475161.20       1 - 1   9.4           9.2           9.0
# 4         1475161.20       2 - 1  27.0          27.0          26.0
# ..               ...         ...   ...           ...           ...
# 177          7270.13    The Draw   5.8           5.7           5.6
# 178        107796.20       1 - 0   6.2           6.4           6.2
# 179        107796.20       1 - 1  13.0          12.0          11.5
# 180         76540.70       3 - 1  16.5          16.0          15.5
# 181        143658.79       1 - 2  25.0          22.0          21.0
#
#      back_price_3  back_size_1  back_size_2  back_size_3  lay_price_1  \
# 0            12.5      2234.39      2436.18      3464.34         14.5
# 1             5.6       540.86      1433.83      1493.76          5.9
# 2            17.5      1421.34       829.58       361.23         19.0
# 3             8.8       159.97      1020.32       435.73          9.6
# 4            25.0       193.71       150.46        44.02         28.0
# ..            ...          ...          ...          ...          ...
# 177           5.5        16.88        68.39        34.37          5.9
# 178           6.0        21.37        32.06        77.90          6.8
# 179          11.0        82.54        18.75        16.79         13.0
# 180          15.0        17.66        51.31        10.36         17.0
# 181          18.5        42.99        10.00        15.59         25.0
#
#      lay_price_2  lay_price_3  lay_size_1  lay_size_2  lay_size_3  \
# 0           15.0         15.5      546.84     2268.94     3771.57
# 1            6.0          6.2      810.35     1071.49     1613.59
# 2           19.5         20.0      203.18      854.01     1279.89
# 3            9.8         10.0     4255.70      249.85       31.02
# 4           29.0         30.0      998.30       31.31      105.01
# ..           ...          ...         ...         ...         ...
# 177          6.2          6.4      107.32      119.93       12.30
# 178          7.0          7.4      100.67       46.70       30.25
# 179         14.0         16.5       67.39       71.82       13.60
# 180         18.0        230.0       78.28       58.97        6.84
# 181         27.0         36.0       61.75       29.49        3.02
#
#     runner_name_general        market_runner  input_odds      pred  pred_odds  \
# 0                  Away      MATCH_ODDS Away        13.5  0.111498   8.968789
# 1                 1 - 0  CORRECT_SCORE 1 - 0         5.8  0.225859   4.427535
# 2                 3 - 1  CORRECT_SCORE 3 - 1        18.5  0.103708   9.642480
# 3                 1 - 1  CORRECT_SCORE 1 - 1         9.2  0.138985   7.195026
# 4                 2 - 1  CORRECT_SCORE 2 - 1        27.0  0.046321  21.588655
# ..                  ...                  ...         ...       ...        ...
# 177            The Draw  MATCH_ODDS The Draw         5.7  0.231310   4.323210
# 178               1 - 0  CORRECT_SCORE 1 - 0         6.4  0.255166   3.919018
# 179               1 - 1  CORRECT_SCORE 1 - 1        12.0  0.107163   9.331577
# 180               3 - 1  CORRECT_SCORE 3 - 1        16.0  0.085268  11.727733
# 181               1 - 2  CORRECT_SCORE 1 - 2        22.0  0.060050  16.652793
#
#      bet  correct_score_overround  match_odds_overround  over_under_overround  \
# 0      1                 0.886220              1.009022              5.036725
# 1      1                 0.890976              1.005528              5.025461
# 2      1                 0.890976              1.005528              5.025461
# 3      1                 0.949564              1.002419              5.027455
# 4      1                 0.949564              1.002419              5.027455
# ..   ...                      ...                   ...                   ...
# 177    1                 0.888762              1.004443              5.115223
# 178    1                 0.888762              1.004443              5.115223
# 179    1                 0.888762              1.004443              5.115223
# 180    1                 0.893720              1.011454              5.145040
# 181    1                 1.001000              1.003074              5.059578
#
#      rn  pred_bookie  odds_pred_ratio  odds_pred_ratio_band  pred_odds_band  \
# 0     1     0.071429         1.505220                   1.5            10.0
# 1     1     0.172414         1.309984                   1.3             5.0
# 2     1     0.052632         1.918594                   1.9            10.0
# 3     1     0.108696         1.278661                   1.3             5.0
# 4     1     0.037037         1.250657                   1.3            20.0
# ..   ..          ...              ...                   ...             ...
# 177   1     0.175439         1.318465                   1.3             5.0
# 178   1     0.156250         1.633062                   1.6             5.0
# 179   1     0.083333         1.285956                   1.3            10.0
# 180   1     0.062500         1.364287                   1.4            10.0
# 181   1     0.045455         1.321100                   1.3            15.0
#
#      bookie_odds_band
# 0                15.0
# 1                 5.0
# 2                20.0
# 3                10.0
# 4                25.0
# ..                ...
# 177               5.0
# 178               5.0
# 179              10.0
# 180              15.0
# 181              20.0
#
# [182 rows x 45 columns]

# %%
predictions_data.groupby('market_type').agg({
    'total_matched_market': [lambda x: np.quantile(x, 0.05),
                             lambda x: np.quantile(x, 0.15),
                             lambda x: np.quantile(x, 0.25),
                             lambda x: np.quantile(x, 0.5),
                             lambda x: np.quantile(x, 0.75),
                             lambda x: np.quantile(x, 0.85),
                             lambda x: np.quantile(x, 0.95)]
})
# Out:
#               total_matched_market                                   \
#                         <lambda_0> <lambda_1> <lambda_2> <lambda_3>
# market_type
# CORRECT_SCORE                0.000    17.8750     62.510     567.27
# MATCH_ODDS                 115.749   467.0265   1742.755    5006.03
# OVER_UNDER_05                6.328    29.3920     83.680     775.23
# OVER_UNDER_35              145.811   369.5930    593.375    1152.83
# OVER_UNDER_45              101.820   101.8200    101.820     101.82
#
#
#                <lambda_4> <lambda_5>  <lambda_6>
# market_type
# CORRECT_SCORE   2241.4750   4086.510   17958.095
# MATCH_ODDS     10532.4575  66402.477  624907.114
# OVER_UNDER_05   1037.3200   7990.304   15459.066
# OVER_UNDER_35   1179.0800   1189.580    1200.080
# OVER_UNDER_45    101.8200    101.820     101.820

# %%
predictions_data['low_total_matched'] = 0
predictions_data.loc[(predictions_data['market_type']=='CORRECT_SCORE') & (predictions_data['total_matched_market']<1000), 'low_total_matched'] = 1
predictions_data.loc[(predictions_data['market_type']=='MATCH_ODDS') & (predictions_data['total_matched_market']<5000), 'low_total_matched'] = 1
predictions_data.loc[(predictions_data['market_type']=='OVER_UNDER_05') & (predictions_data['total_matched_market']<1000), 'low_total_matched'] = 1
predictions_data.loc[(predictions_data['market_type']=='OVER_UNDER_35') & (predictions_data['total_matched_market']<1000), 'low_total_matched'] = 1

# %%
predictions_data.groupby('low_total_matched').agg({
    'bet_id': len,
    'bet_outcome': lambda x: sum(np.array(x)=='WON'),
    'profit': sum
}).reset_index().sort_values('low_total_matched')
# Out:
#    low_total_matched  bet_id  bet_outcome  profit
# 0                  0      75            7  -59.44
# 1                  1     107           14   92.61

# %%
predictions_data.groupby(['low_total_matched', 'market_type']).agg({
    'bet_id': len,
    'bet_outcome': lambda x: sum(np.array(x)=='WON'),
    'profit': sum
}).reset_index().sort_values(['market_type', 'low_total_matched'])
# Out:
#    low_total_matched    market_type  bet_id  bet_outcome  profit
# 0                  0  CORRECT_SCORE      59            2  -84.60
# 5                  1  CORRECT_SCORE      92            8   57.00
# 1                  0     MATCH_ODDS       9            3   30.20
# 6                  1     MATCH_ODDS       9            5   44.09
# 2                  0  OVER_UNDER_05       4            0   -8.00
# 7                  1  OVER_UNDER_05       5            0  -10.00
# 3                  0  OVER_UNDER_35       2            1   -0.52
# 8                  1  OVER_UNDER_35       1            1    1.52
# 4                  0  OVER_UNDER_45       1            1    3.48

# %%
predictions_data['minutes_to_event'].describe()
# Out:
# count     182.000000
# mean      363.550092
# std       282.398163
# min        18.750000
# 25%       145.700000
# 50%       320.958333
# 75%       527.666667
# max      1311.116667
# Name: minutes_to_event, dtype: float64

# %%
predictions_data['long_before'] = (predictions_data['minutes_to_event']>120)*1
predictions_data.groupby(['long_before', 'market_type']).agg({
    'bet_id': len,
    'bet_outcome': lambda x: sum(np.array(x)=='WON'),
    'profit': sum
}).reset_index().sort_values(['market_type', 'long_before'])
# Out:
#    long_before    market_type  bet_id  bet_outcome  profit
# 0            0  CORRECT_SCORE      28            0  -56.00
# 4            1  CORRECT_SCORE     123           10   28.40
# 1            0     MATCH_ODDS       3            2   29.89
# 5            1     MATCH_ODDS      15            6   44.40
# 2            0  OVER_UNDER_05       4            0   -8.00
# 6            1  OVER_UNDER_05       5            0  -10.00
# 3            0  OVER_UNDER_35       1            0   -2.00
# 7            1  OVER_UNDER_35       2            2    3.00
# 8            1  OVER_UNDER_45       1            1    3.48

# %%
predictions_data['lay_back_gap'] = predictions_data['lay_price_1'] - predictions_data['back_price_1']
predictions_data['lay_back_gap_pc'] = predictions_data['lay_back_gap']/predictions_data['back_price_1']

# %%
predictions_data.loc[predictions_data['lay_back_gap'].isnull(), 'lay_back_gap'] = 999
predictions_data.loc[predictions_data['lay_back_gap_pc'].isnull(), 'lay_back_gap_pc'] = 999

# %%
predictions_data['lay_back_gap_pc'].describe()
# Out:
# count    182.000000
# mean      38.648382
# std      192.600556
# min        0.017241
# 25%        0.066667
# 50%        0.101724
# 75%        0.262500
# max      999.000000
# Name: lay_back_gap_pc, dtype: float64

# %%
predictions_data['big_lay_back_gap_pc'] = (predictions_data['lay_back_gap_pc']>0.1)*1
predictions_data.groupby(['big_lay_back_gap_pc']).agg({
    'bet_id': len,
    'bet_outcome': lambda x: sum(np.array(x)=='WON'),
    'profit': sum
}).reset_index().sort_values('big_lay_back_gap_pc')
# Out:
#    big_lay_back_gap_pc  bet_id  bet_outcome  profit
# 0                    0      91           14   83.00
# 1                    1      91            7  -49.83

# %%
predictions_data.groupby(['big_lay_back_gap_pc', 'market_type']).agg({
    'bet_id': len,
    'bet_outcome': lambda x: sum(np.array(x)=='WON'),
    'profit': sum
}).reset_index().sort_values(['market_type', 'big_lay_back_gap_pc'])
# Out:
#    big_lay_back_gap_pc    market_type  bet_id  bet_outcome  profit
# 0                    0  CORRECT_SCORE      71            7   44.40
# 4                    1  CORRECT_SCORE      80            3  -72.00
# 1                    0     MATCH_ODDS      15            5   41.60
# 5                    1     MATCH_ODDS       3            3   32.69
# 2                    0  OVER_UNDER_05       2            0   -4.00
# 6                    1  OVER_UNDER_05       7            0  -14.00
# 3                    0  OVER_UNDER_35       3            2    1.00
# 7                    1  OVER_UNDER_45       1            1    3.48

# %%
predictions_data.groupby(['big_lay_back_gap_pc', 'long_before']).agg({
    'bet_id': len,
    'bet_outcome': lambda x: sum(np.array(x)=='WON'),
    'profit': sum
}).reset_index().sort_values(['big_lay_back_gap_pc', 'long_before'])
# Out:
#    big_lay_back_gap_pc  long_before  bet_id  bet_outcome  profit
# 0                    0            0      19            1  -10.00
# 1                    0            1      72           13   93.00
# 2                    1            0      17            1  -26.11
# 3                    1            1      74            6  -23.72

# %%
predictions_data.groupby(['big_lay_back_gap_pc', 'long_before', 'low_total_matched']).agg({
    'bet_id': len,
    'bet_outcome': lambda x: sum(np.array(x)=='WON'),
    'profit': sum
}).reset_index().sort_values(['big_lay_back_gap_pc', 'long_before', 'low_total_matched'])
# Out:
#    big_lay_back_gap_pc  long_before  low_total_matched  bet_id  bet_outcome  \
# 0                    0            0                  0      16            1
# 1                    0            0                  1       3            0
# 2                    0            1                  0      45            5
# 3                    0            1                  1      27            8
# 4                    1            0                  0       2            0
# 5                    1            0                  1      15            1
# 6                    1            1                  0      12            1
# 7                    1            1                  1      62            5
#
#    profit
# 0   -4.00
# 1   -6.00
# 2  -32.92
# 3  125.92
# 4   -4.00
# 5  -22.11
# 6  -18.52
# 7   -5.20

# %%
predictions_data.groupby(['big_lay_back_gap_pc', 'long_before', 'market_type']).agg({
    'bet_id': len,
    'bet_outcome': lambda x: sum(np.array(x)=='WON'),
    'profit': sum
}).reset_index().sort_values(['big_lay_back_gap_pc', 'long_before', 'market_type'])
# Out:
#     big_lay_back_gap_pc  long_before    market_type  bet_id  bet_outcome  \
# 0                     0            0  CORRECT_SCORE      14            0
# 1                     0            0     MATCH_ODDS       2            1
# 2                     0            0  OVER_UNDER_05       2            0
# 3                     0            0  OVER_UNDER_35       1            0
# 4                     0            1  CORRECT_SCORE      57            7
# 5                     0            1     MATCH_ODDS      13            4
# 6                     0            1  OVER_UNDER_35       2            2
# 7                     1            0  CORRECT_SCORE      14            0
# 8                     1            0     MATCH_ODDS       1            1
# 9                     1            0  OVER_UNDER_05       2            0
# 10                    1            1  CORRECT_SCORE      66            3
# 11                    1            1     MATCH_ODDS       2            2
# 12                    1            1  OVER_UNDER_05       5            0
# 13                    1            1  OVER_UNDER_45       1            1
#
#     profit
# 0   -28.00
# 1    24.00
# 2    -4.00
# 3    -2.00
# 4    72.40
# 5    17.60
# 6     3.00
# 7   -28.00
# 8     5.89
# 9    -4.00
# 10  -44.00
# 11   26.80
# 12  -10.00
# 13    3.48

# %% [markdown]
# #### Is it bad to do too many bets on same event?

# %%
event_bets = predictions_data.groupby('event_id').size().reset_index().rename(columns={0: 'event_total_bets'})
predictions_data_with_event_counts = predictions_data.merge(event_bets, how='left', on='event_id')

# %%
predictions_data_with_event_counts.groupby(['event_total_bets']).agg({
    'bet_id': len,
    'bet_outcome': lambda x: sum(np.array(x)=='WON'),
    'profit': sum
}).reset_index().sort_values(['event_total_bets'])
# Out:
#    event_total_bets  bet_id  bet_outcome  profit
# 0                 1      55            5   61.00
# 1                 2      44            6   16.69
# 2                 3      24            7   41.20
# 3                 4      36            2  -43.20
# 4                 5       5            1   -6.52
# 5                 6      18            0  -36.00
