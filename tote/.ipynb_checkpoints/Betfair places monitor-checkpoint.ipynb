# %% [markdown]
# # Betfair Places Monitor

# %%
import requests
import urllib
import json
import pandas as pd
import numpy as np
import pickle
from tqdm import tqdm_notebook
import datetime
import time
import importlib
import config
importlib.reload(config)
from config import username, password, application, dbpw
import logging

import matplotlib.pyplot as plt
import seaborn as sns

import pymysql
import sqlalchemy

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
pd.options.mode.chained_assignment = None

# %%
pd.options.display.max_columns = 100
pd.options.display.max_rows = 100

# %% [markdown]
# ## Get Results

# %% [markdown]
# #### Get bets from DB

# %%
connect_string = 'mysql+pymysql://root:'+dbpw+'@localhost/betfair'
sql_engine = sqlalchemy.create_engine(connect_string)
placed_bets = pd.read_sql('''
                        SELECT DISTINCT o.selection_id, o.market_id, o.side, o.bet_id
                        FROM order_results_live o
                        LEFT JOIN bet_outcomes_live b
                                    ON o.market_id = b.market_id
                                    AND o.selection_id = b.selection_id
                                    AND o.side = b.side
                                    AND o.bet_id = b.bet_id
                        WHERE order_status = 'EXECUTION_COMPLETE'
                        AND b.market_id IS NULL
                        
                        ''',
                      con=sql_engine)

# %%
len(placed_bets)
# Out:
# 2

# %%
placed_bets
# Out:
#    selection_id    market_id  side        bet_id
# 0      13139055  1.183617302  BACK  233908539167
# 1      20377407  1.183617317   LAY  233931499692

# %% [markdown]
# #### Login to betfair

# %%
header = {'X-Application': application, 'Content-Type': 'application/x-www-form-urlencoded'}
auth = 'username='+username+'&password='+password

login = requests.post('https://identitysso-cert.betfair.com/api/certlogin',
                      cert=('/etc/ssl/client-2048.crt', '/etc/ssl/client-2048.key'),
                      headers=header, data=auth)

login_success = login.json()['loginStatus']
logging.info('Login '+str(login_success))

# %%
ssoid = login.json()['sessionToken']
headers = {'X-Application': application, 'X-Authentication': ssoid, 'content-type': 'application/json'}

# %% [markdown]
# #### Get bet outcomes

# %%
bet_url = "https://api.betfair.com/exchange/betting/json-rpc/v1"

# %%
markets = list(placed_bets['market_id'])
bet_outcomes = []
for m in markets:
    
    # get settled bets
    outcome_req = '{"jsonrpc": "2.0", "method": "SportsAPING/v1.0/listClearedOrders",\
                    "params": {"marketIds": ["' + str(m) + '"], "betStatus": "SETTLED"}, "id": 1}'
    request = requests.post(bet_url, data=outcome_req.encode('utf-8'), headers=headers)
    outcome_result = request.json()
    bet_outcomes += outcome_result['result']['clearedOrders']
    
    # get voided bets
    outcome_req = '{"jsonrpc": "2.0", "method": "SportsAPING/v1.0/listClearedOrders",\
                    "params": {"marketIds": ["' + str(m) + '"], "betStatus": "VOIDED"}, "id": 1}'
    request = requests.post(bet_url, data=outcome_req.encode('utf-8'), headers=headers)
    outcome_result = request.json()
    bet_outcomes += outcome_result['result']['clearedOrders']
    
#     # cancelled
#     outcome_req = '{"jsonrpc": "2.0", "method": "SportsAPING/v1.0/listClearedOrders",\
#                     "params": {"marketIds": ["' + str(m) + '"], "betStatus": "CANCELLED"}, "id": 1}'
#     request = requests.post(bet_url, data=outcome_req.encode('utf-8'), headers=headers)
#     outcome_result = request.json()
#     bet_outcomes += outcome_result['result']['clearedOrders']
    
#     # lapsed
#     outcome_req = '{"jsonrpc": "2.0", "method": "SportsAPING/v1.0/listClearedOrders",\
#                     "params": {"marketIds": ["' + str(m) + '"], "betStatus": "LAPSED"}, "id": 1}'
#     request = requests.post(bet_url, data=outcome_req.encode('utf-8'), headers=headers)
#     outcome_result = request.json()
#     bet_outcomes += outcome_result['result']['clearedOrders']

# %%
def parse_bet_outcome(bet_outcome):
    return [
        bet_outcome.get('eventTypeId', None),
        bet_outcome.get('eventId', None),
        bet_outcome.get('marketId', None),
        bet_outcome.get('selectionId', None),
        bet_outcome.get('handicap', None),
        bet_outcome.get('betId', None),
        bet_outcome.get('placedDate', None),
        bet_outcome.get('persistenceType', None),
        bet_outcome.get('orderType', None),
        bet_outcome.get('side', None),
        bet_outcome.get('betOutcome', None),
        bet_outcome.get('priceRequested', None),
        bet_outcome.get('settledDate', None),
        bet_outcome.get('lastMatchedDate', None),
        bet_outcome.get('betCount', None),
        bet_outcome.get('priceMatched', None),
        bet_outcome.get('priceReduced', None),
        bet_outcome.get('sizeSettled', None),
        bet_outcome.get('sizeCancelled', None),
        bet_outcome.get('profit', None),
    ]

outcome_cols = ['event_type_id', 'event_id', 'market_id', 'selection_id', 'handicap', 'bet_id', 'placed_date', 'persistence_type',
                'order_type', 'side', 'bet_outcome', 'price_requested', 'settled_date', 'last_matched_date', 'bet_count', 'price_matched',
                'price_reduced', 'size_settled', 'size_cancelled', 'profit']

# %%
bet_outcomes_df = pd.DataFrame([parse_bet_outcome(b) for b in bet_outcomes], columns=outcome_cols)

# %%
len(bet_outcomes_df)
# Out:
# 2

# %%
bet_outcomes_df = bet_outcomes_df[bet_outcomes_df['bet_id'].isin(placed_bets['bet_id'])].groupby(['selection_id', 'market_id', 'bet_id']).head(1)

# %%
len(bet_outcomes_df)
# Out:
# 2

# %% [markdown]
# #### Send to DB

# %%
connect_string = 'mysql+pymysql://root:'+dbpw+'@localhost/betfair'
sql_engine = sqlalchemy.create_engine(connect_string)

# %%
bet_outcomes_df.to_sql(name='bet_outcomes_live', con=sql_engine, schema='betfair', if_exists='append', index=False)

# %% [markdown]
# ## Get all bets with results to monitor

# %%
connect_string = 'mysql+pymysql://root:'+dbpw+'@localhost/betfair'
sql_engine = sqlalchemy.create_engine(connect_string)
bet_outcomes_full = pd.read_sql('''
                                SELECT * FROM bet_outcomes_live
                                ''',
                                con=sql_engine)

# %%
# lay liab
bet_outcomes_full['liab'] = (bet_outcomes_full['price_matched']-1)*bet_outcomes_full['size_settled']

# back liab
bet_outcomes_full.loc[bet_outcomes_full['side']=='BACK', 'liab'] = bet_outcomes_full.loc[bet_outcomes_full['side']=='BACK', 'size_settled']

# void liab
bet_outcomes_full.loc[bet_outcomes_full['profit']==0, 'liab'] = 0

# %%
print(f"Total Bets: {sum(bet_outcomes_full['liab']!=0)}")
print(f"Total Liability: £{sum(bet_outcomes_full['liab'])}")
print(f"Total Return: £{round(sum(bet_outcomes_full['liab'] + bet_outcomes_full['profit']),2)}")
print(f"Total Profit: £{sum(bet_outcomes_full['profit'])}")
print(f"Profit Margin: {round(100*(sum(bet_outcomes_full['profit'])/sum(bet_outcomes_full['liab'])),2)}%")
# Out:
# Total Bets: 171
# Total Liability: £327.94000000000005
# Total Return: £268.86
# Total Profit: £-59.08000000000001
# Profit Margin: -18.02%

# %% [markdown]
# ##### Note: additional £18 profit from £30 bet on first test day pre DB integration

# %%
36/130
# Out:
# 0.27692307692307694

# %% [markdown]
# ## Daily results

# %%
bet_outcomes_full['settled_day'] = pd.to_datetime(bet_outcomes_full['settled_date'], utc=True).dt.date

# %%
daily_aggs = bet_outcomes_full.groupby('settled_day')['liab', 'profit'].sum().reset_index().sort_values('settled_day')
daily_aggs['liab_cumulative'] = daily_aggs['liab'].cumsum()
daily_aggs['profit_cumulative'] = daily_aggs['profit'].cumsum()

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 7))

sns.lineplot(data=daily_aggs, x='settled_day', y='profit_cumulative', ax=ax, label='Cumulative Profit').set_title('Daily and Cumulative Profit')
sns.lineplot(data=daily_aggs, x='settled_day', y='profit', ax=ax, label='Daily Profit')

# %% [markdown]
# ## Need to add in commission and add breakdowns

# %% [markdown]
# ## Odds movements after predictions

# %%
connect_string = 'mysql+pymysql://root:'+dbpw+'@localhost/betfair'
sql_engine = sqlalchemy.create_engine(connect_string)
predictions_data = pd.read_sql('''
                        SELECT * FROM predictions_output_live
                        ''',
                      con=sql_engine)

# %%
predictions_data.head(3)
# Out:
#    runner_id     runner_name  status    market_id market_type market_id_win  \
# 0   27753127  Vitesse Du Son  ACTIVE  1.183146812       PLACE   1.183146811
# 1   27145235       Courtland  ACTIVE  1.183147423       PLACE   1.183147422
# 2   17012325  Dark Crocodile  ACTIVE  1.183146812       PLACE   1.183146811
#
#   market_id_place   api_call_time_utc  handicap  ltp  total_matched  \
# 0     1.183146812 2021-05-10 08:23:18       0.0  NaN            0.0
# 1     1.183147423 2021-05-10 08:23:18       0.0  NaN            0.0
# 2     1.183146812 2021-05-10 08:23:18       0.0  NaN            0.0
#
#    back_price_1  back_price_2  back_price_3  back_size_1  back_size_2  \
# 0          1.43          1.42          1.15        46.77        43.27
# 1          2.10          1.99          1.97        11.80        26.90
# 2          1.92          1.88          1.24        21.50        41.56
#
#    back_size_3  lay_price_1  lay_price_2  lay_price_3  lay_size_1  lay_size_2  \
# ...

# %% [markdown]
# #### Generate a few factors of interest

# %%
predictions_data['back_lay_gap_abs'] = predictions_data['lay_price_1'] - predictions_data['back_price_1']
predictions_data['back_lay_gap_pc'] = 100*(predictions_data['lay_price_1']/predictions_data['back_price_1']-1)

# %%
predictions_data['back_pred_odds_gap_abs'] = predictions_data['pred_odds'] - predictions_data['back_price_1']
predictions_data['back_pred_odds_gap_pc'] = 100*(predictions_data['pred_odds']/predictions_data['back_price_1']-1)

predictions_data['lay_pred_odds_gap_abs'] = predictions_data['pred_odds'] - predictions_data['lay_price_1']
predictions_data['lay_pred_odds_gap_pc'] = 100*(predictions_data['pred_odds']/predictions_data['lay_price_1']-1)

# %%
last_predictions = predictions_data.sort_values('api_call_time_utc').groupby(['runner_id', 'market_id']).tail(1)

# %%
predictions_data = predictions_data.merge(
    last_predictions[['runner_id', 'market_id', 'back_price_1', 'lay_price_1', 'number_of_runners']].rename(
        columns={'back_price_1': 'back_price_1_final', 'lay_price_1': 'lay_price_1_final', 'number_of_runners': 'number_of_runners_final'}))

# %%
predictions_data['back_final_back_gap_abs'] = predictions_data['back_price_1_final'] - predictions_data['back_price_1']
predictions_data['back_final_back_gap_pc'] = 100*(predictions_data['back_price_1_final']/predictions_data['back_price_1']-1)

predictions_data['lay_final_lay_gap_abs'] = predictions_data['lay_price_1_final'] - predictions_data['lay_price_1']
predictions_data['lay_final_lay_gap_pc'] = 100*(predictions_data['lay_price_1_final']/predictions_data['lay_price_1']-1)

# %%
limits = 1
ax= predictions_data[
    (predictions_data['minutes_to_event_rounded']==300) &
    (predictions_data['number_of_runners']==predictions_data['number_of_runners_final']) &
    (predictions_data['back_lay_gap_pc']<5)].head(1000).tail(1000).plot(
    kind='scatter', x='back_pred_odds_gap_abs', y='back_final_back_gap_abs', alpha=0.4, xlim=(-limits, limits), ylim=(-limits, limits))
ax.vlines(x=0, ymin=-limits, ymax=limits, linestyle='dashed')
ax.hlines(y=0, xmin=-limits, xmax=limits, linestyle='dashed')

# %%
limits = 1
ax= predictions_data[
    (predictions_data['minutes_to_event_rounded']==180) &
    (predictions_data['number_of_runners']==predictions_data['number_of_runners_final']) &
    (predictions_data['back_lay_gap_pc']<5)].head(10000).tail(10000).plot(
    kind='scatter', x='lay_pred_odds_gap_abs', y='lay_final_lay_gap_abs', alpha=0.4, xlim=(-limits, limits), ylim=(-limits, limits))
ax.vlines(x=0, ymin=-limits, ymax=limits, linestyle='dashed')
ax.hlines(y=0, xmin=-limits, xmax=limits, linestyle='dashed')

# %% [markdown]
# #### Notes
# * When back_lay_gap_pc > 100 looks like there's a lot of times the predicted odds are less than actual but then the odds end up lengthening
# * Quantify for different gap %s
# * Looks like when the back_lay_gap_pc < 10 and the back_pred_odds_gap_abs < -0.2ish there is consistent value found
# * Remember that the final odds can be wrong too though, i.e. model could still be finding good value even if final odds suggest otherwise

# %% [markdown]
# #### Combine above with successful bet orders and outcomes

# %%
connect_string = 'mysql+pymysql://root:'+dbpw+'@localhost/betfair'
sql_engine = sqlalchemy.create_engine(connect_string)
combined_outcome_data = pd.read_sql('''
                        WITH last_predictions AS (
                            SELECT *, CASE WHEN back=1 THEN 'BACK' WHEN lay=1 THEN 'LAY' ELSE NULL END AS side,
                                    ROW_NUMBER() OVER (PARTITION BY runner_id, market_id, back, lay ORDER BY api_call_time_utc DESC) AS rn
                            FROM predictions_output_live
                            WHERE back = 1 OR lay = 1
                            )
                        select o.market_id, o.selection_id, o.size, o.price, o.side, o.average_price_matched,
                                b.placed_date, b.bet_outcome, b.settled_date, b.price_matched, b.price_reduced,
                                b.size_settled, b.size_cancelled, b.profit,
                                p.runner_name, p.api_call_time_utc, p.back_price_1, p.lay_price_1, p.venue, p.event_name,
                                p.race_type, p.number_of_runners_orig, p.number_of_runners, p.p_sum, p.minutes_to_event_rounded,
                                p.preds, p.pred_odds, p.back, p.lay
                        from order_results_live o
                        LEFT JOIN bet_outcomes_live b
                                ON o.market_id = b.market_id
                                AND o.selection_id = b.selection_id
                                AND o.side = b.side
                                AND o.bet_id = b.bet_id
                        LEFT JOIN (SELECT * FROM last_predictions WHERE rn=1) p
                                ON o.market_id = p.market_id
                                AND o.selection_id = p.runner_id
                                AND o.side = p.side
                        WHERE o.order_status = 'EXECUTION_COMPLETE'
                        
                        ''',
                      con=sql_engine)

# %%
combined_outcome_data.head(10)
# Out:
#      market_id  selection_id  size  price  side  average_price_matched  \
# 0  1.183147433       9052305   2.0   4.80  BACK                 4.8000
# 1  1.183146812      20936197   2.0   4.80  BACK                 4.9560
# 2  1.183147453      38432854   2.0   1.45   LAY                 1.4500
# 3  1.183147433      12533633   2.0   4.60  BACK                 4.6000
# 4  1.183146822      19148745   2.0   4.80  BACK                 4.9000
# 5  1.183146832      31597925   2.0   4.70  BACK                 4.7995
# 6  1.183154137      14569324   2.0   3.60  BACK                 3.7500
# 7  1.183154157      15926503   2.0   2.26   LAY                 2.2600
# 8  1.183153243      38480221   2.0   4.30  BACK                 4.4000
# 9  1.183153243      28575456   2.0   1.50   LAY                 1.5000
#
#                 placed_date bet_outcome              settled_date  \
# 0  2021-05-10T10:14:41.000Z        LOST  2021-05-10T13:49:02.000Z
# ...

# %%
combined_outcome_data['back_lay_gap_abs'] = combined_outcome_data['lay_price_1'] - combined_outcome_data['back_price_1']
combined_outcome_data['back_lay_gap_pc'] = 100*(combined_outcome_data['lay_price_1']/combined_outcome_data['back_price_1']-1)

# %%
combined_outcome_data['back_pred_odds_gap_abs'] = combined_outcome_data['pred_odds'] - combined_outcome_data['back_price_1']
combined_outcome_data['back_pred_odds_gap_pc'] = 100*(combined_outcome_data['pred_odds']/combined_outcome_data['back_price_1']-1)

combined_outcome_data['lay_pred_odds_gap_abs'] = combined_outcome_data['pred_odds'] - combined_outcome_data['lay_price_1']
combined_outcome_data['lay_pred_odds_gap_pc'] = 100*(combined_outcome_data['pred_odds']/combined_outcome_data['lay_price_1']-1)

# %%
combined_outcome_data['back_lay_gap_abs_band'] = pd.cut(combined_outcome_data['back_lay_gap_abs'], bins=[-999, 0.25, 1, 2, 3, 5, 10, 99999])
combined_outcome_data['back_lay_gap_pc_band'] = pd.cut(combined_outcome_data['back_lay_gap_pc'], bins=[-999, 10, 25, 50, 100, 200, 99999])

# %%
combined_outcome_data.head(5)
# Out:
#      market_id  selection_id  size  price  side  average_price_matched  \
# 0  1.183147433       9052305   2.0   4.80  BACK                  4.800
# 1  1.183146812      20936197   2.0   4.80  BACK                  4.956
# 2  1.183147453      38432854   2.0   1.45   LAY                  1.450
# 3  1.183147433      12533633   2.0   4.60  BACK                  4.600
# 4  1.183146822      19148745   2.0   4.80  BACK                  4.900
#
#                 placed_date bet_outcome              settled_date  \
# 0  2021-05-10T10:14:41.000Z        LOST  2021-05-10T13:49:02.000Z
# 1  2021-05-10T11:22:50.000Z         WON  2021-05-10T12:59:20.000Z
# 2  2021-05-10T11:38:34.000Z         WON  2021-05-10T15:57:50.000Z
# 3  2021-05-10T12:34:48.000Z        LOST  2021-05-10T13:49:02.000Z
# 4  2021-05-10T12:45:21.000Z        LOST  2021-05-10T14:10:30.000Z
#
#    price_matched  price_reduced  size_settled size_cancelled  profit  \
# ...

# %%
combined_outcome_data.groupby('back_lay_gap_abs_band').agg({
    'selection_id': len,
    'profit': sum})
# Out:
#                        selection_id  profit
# back_lay_gap_abs_band
# (-999.0, 0.25]                   44   -1.73
# (0.25, 1.0]                      55  -29.40
# (1.0, 2.0]                       30    8.15
# (2.0, 3.0]                        9  -11.80
# (3.0, 5.0]                       11   -6.20
# (5.0, 10.0]                       6   16.40
# (10.0, 99999.0]                  20  -33.62

# %%
combined_outcome_data.groupby('back_lay_gap_pc_band').agg({
    'selection_id': len,
    'profit': sum})
# Out:
#                       selection_id  profit
# back_lay_gap_pc_band
# (-999, 10]                      45   -9.13
# (10, 25]                        49  -11.30
# (25, 50]                        29   -4.89
# (50, 100]                       24  -19.26
# (100, 200]                       8   20.00
# (200, 99999]                    20  -33.62

# %%
combined_outcome_data['average_price_matched_band'] = combined_outcome_data['average_price_matched'].apply(np.round)
combined_outcome_data.groupby('average_price_matched_band').agg({
    'selection_id': len,
    'profit': sum
})
# Out:
#                             selection_id  profit
# average_price_matched_band
# 1.0                                   12    0.88
# 2.0                                   28   12.50
# 3.0                                   31  -15.42
# 4.0                                   62  -33.12
# 5.0                                   43  -19.92
# 6.0                                    1   -2.00
# 8.0                                    1   -2.00

# %%
combined_outcome_data.groupby('side').agg({
    'selection_id': len,
    'profit': sum
})
# Out:
#       selection_id  profit
# side
# BACK           140  -64.65
# LAY             38    5.57

# %%
combined_outcome_data.groupby('minutes_to_event_rounded').agg({
    'selection_id': len,
    'profit': sum
})
# Out:
#                           selection_id  profit
# minutes_to_event_rounded
# 60                                  32  -12.90
# 120                                 37    2.59
# 180                                 35   -4.50
# 240                                 27   -6.29
# 300                                 47  -37.98

# %%
combined_outcome_data.groupby(['minutes_to_event_rounded', 'side']).agg({
    'selection_id': len,
    'profit': sum
})
# Out:
#                                selection_id  profit
# minutes_to_event_rounded side
# 60                       BACK            27  -15.18
#                          LAY              5    2.28
# 120                      BACK            24   -3.55
#                          LAY             13    6.14
# 180                      BACK            30   -0.16
#                          LAY              5   -4.34
# 240                      BACK            15   -9.86
#                          LAY             12    3.57
# 300                      BACK            44  -35.90
#                          LAY              3   -2.08

# %%
combined_outcome_data.groupby(['average_price_matched_band', 'side']).agg({
    'selection_id': len,
    'profit': sum
})
# Out:
#                                  selection_id  profit
# average_price_matched_band side
# 1.0                        LAY             12    0.88
# 2.0                        BACK             6    5.65
#                            LAY             22    6.85
# 3.0                        BACK            27  -13.26
#                            LAY              4   -2.16
# 4.0                        BACK            62  -33.12
# 5.0                        BACK            43  -19.92
# 6.0                        BACK             1   -2.00
# 8.0                        BACK             1   -2.00

# %%
combined_outcome_data.groupby(['minutes_to_event_rounded', 'average_price_matched_band', 'side']).agg({
    'selection_id': len,
    'profit': sum
})
# Out:
#                                                           selection_id  profit
# minutes_to_event_rounded average_price_matched_band side
# 60                       1.0                        LAY              3   -1.72
#                          2.0                        BACK             3    3.45
#                                                     LAY              2    4.00
#                          3.0                        BACK             9    1.46
#                          4.0                        BACK            10  -20.00
#                          5.0                        BACK             5   -0.09
# 120                      1.0                        LAY              3   -1.74
#                          2.0                        LAY              8    8.76
#                          3.0                        BACK             2   -4.00
#                                                     LAY              2   -0.88
# ...

# %% [markdown]
# #### With above analysis, also want to check overround and compare to last available odds not just win %s
