# %% [markdown]
# # Betfair getting odds and placing bets - footall

# %% [markdown]
# #### Useful links
#
# * https://docs.developer.betfair.com/display/1smk3cen4v3lu3yomq5qye0ni/Betting+Enums#BettingEnums-MarketProjection for api method params

# %%
import requests
import urllib
import json
import pandas as pd
import numpy as np
import pickle
from tqdm import tqdm_notebook
import datetime
import importlib
import config
importlib.reload(config)
from config import username, password, application, dbpw
import logging

import matplotlib.pyplot as plt
import seaborn as sns

import pymysql
import sqlalchemy

import xgboost as xgb
import statsmodels.api as sm

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
pd.options.mode.chained_assignment = None

# %%
pd.options.display.max_columns = 100
pd.options.display.max_rows = 100

# %%
logging.basicConfig(filename='example.log', level=logging.INFO, format='%(asctime)s, %(levelname)s: %(message)s')

# %% [markdown]
# ## Load models

# %%
# football models
with open('/home/angus/projects/betting/tote/models/football_models_2.pickle', 'rb') as f:
    football_models = pickle.load(f)

# %% [markdown]
# ## Get currently open bets

# %%
# GET EXISTING BETS FROM DB
connect_string = 'mysql+pymysql://root:'+dbpw+'@localhost/betfair'
sql_engine = sqlalchemy.create_engine(connect_string)
existing_bets = pd.read_sql('''
                        SELECT DISTINCT selection_id as runner_id, market_id, side as existing_side, 1 AS existing_bet 
                        FROM football_order_results_live
                        WHERE order_status = 'EXECUTION_COMPLETE'
                        AND CAST(left(placed_date,10) AS DATETIME) >= DATE_ADD(curdate(), INTERVAL -1 DAY)
                      ''',
                      con=sql_engine)
existing_back_bets = existing_bets[existing_bets['existing_side']=='BACK']
existing_lay_bets = existing_bets[existing_bets['existing_side']=='LAY']

# %% [markdown]
# ## Sign in

# %%
try:

    header = {'X-Application': application, 'Content-Type': 'application/x-www-form-urlencoded'}
    auth = 'username='+username+'&password='+password

    login = requests.post('https://identitysso-cert.betfair.com/api/certlogin',
                          cert=('/etc/ssl/client-2048.crt', '/etc/ssl/client-2048.key'),
                          headers=header, data=auth)
    
    login_success = login.json()['loginStatus']
    logging.info('Login '+str(login_success))

except Exception as error:
    login_status_code = login.status_code
    logging.error(error + 'Login error '+str(login_status_code))
    
    # after logging will want to either pass (continue with code below), continue (go back to start of loop perhaps with a pause first) or break

# %%
login.json()
# Out:
# {'sessionToken': 'qZKHow1FCZSFg2uD75fOTuCpcyz+1fHgBJ4KhS68rMQ=',
#  'loginStatus': 'SUCCESS'}

# %%
login.status_code
# Out:
# 200

# %%
ssoid = login.json()['sessionToken']

# %% [markdown]
# ## Get event types

# %%
bet_url = "https://api.betfair.com/exchange/betting/json-rpc/v1"
event_req = '{"jsonrpc": "2.0", "method": "SportsAPING/v1.0/listEventTypes", "params": {"filter":{ }}, "id": 1}'
headers = {'X-Application': application, 'X-Authentication': ssoid, 'content-type': 'application/json'}
request = requests.post(bet_url, data=event_req.encode('utf-8'), headers=headers) 
request.json()
# Out:
# {'jsonrpc': '2.0',
#  'result': [{'eventType': {'id': '1', 'name': 'Soccer'}, 'marketCount': 8047},
#   {'eventType': {'id': '2', 'name': 'Tennis'}, 'marketCount': 1509},
#   {'eventType': {'id': '3', 'name': 'Golf'}, 'marketCount': 112},
#   {'eventType': {'id': '4', 'name': 'Cricket'}, 'marketCount': 246},
#   {'eventType': {'id': '5', 'name': 'Rugby Union'}, 'marketCount': 46},
#   {'eventType': {'id': '1477', 'name': 'Rugby League'}, 'marketCount': 81},
#   {'eventType': {'id': '6', 'name': 'Boxing'}, 'marketCount': 69},
#   {'eventType': {'id': '7', 'name': 'Horse Racing'}, 'marketCount': 865},
#   {'eventType': {'id': '8', 'name': 'Motor Sport'}, 'marketCount': 17},
#   {'eventType': {'id': '27454571', 'name': 'Esports'}, 'marketCount': 84},
#   {'eventType': {'id': '10', 'name': 'Special Bets'}, 'marketCount': 3},
#   {'eventType': {'id': '998917', 'name': 'Volleyball'}, 'marketCount': 7},
#   {'eventType': {'id': '11', 'name': 'Cycling'}, 'marketCount': 1},
#   {'eventType': {'id': '2152880', 'name': 'Gaelic Games'}, 'marketCount': 56},
#   {'eventType': {'id': '3988', 'name': 'Athletics'}, 'marketCount': 1},
#   {'eventType': {'id': '6422', 'name': 'Snooker'}, 'marketCount': 3},
#   {'eventType': {'id': '7511', 'name': 'Baseball'}, 'marketCount': 42},
#   {'eventType': {'id': '6423', 'name': 'American Football'},
#    'marketCount': 59},
#   {'eventType': {'id': '606611', 'name': 'Netball'}, 'marketCount': 7},
#   {'eventType': {'id': '7522', 'name': 'Basketball'}, 'marketCount': 72},
#   {'eventType': {'id': '27589895', 'name': 'Olympics'}, 'marketCount': 1},
#   {'eventType': {'id': '7524', 'name': 'Ice Hockey'}, 'marketCount': 37},
#   {'eventType': {'id': '61420', 'name': 'Australian Rules'},
#    'marketCount': 107},
#   {'eventType': {'id': '468328', 'name': 'Handball'}, 'marketCount': 30},
#   {'eventType': {'id': '3503', 'name': 'Darts'}, 'marketCount': 9},
#   {'eventType': {'id': '26420387', 'name': 'Mixed Martial Arts'},
#    'marketCount': 49},
#   {'eventType': {'id': '4339', 'name': 'Greyhound Racing'},
#    'marketCount': 526},
#   {'eventType': {'id': '2378961', 'name': 'Politics'}, 'marketCount': 48}],
#  'id': 1}

# %% [markdown]
# ## Get countries and football competition ids
# Requesting all markets at once is too much so will likely have to loop over competitions and possibly even market types within each competition to get all data

# %% [markdown]
# ## Get specific football markets (event id 1)

# %% [markdown]
# #### FIrst get events from each country separately

# %%
all_countries = ['', 'AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AW', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BG', 'BH', 'BN', 'BO', 'BR', 'BY',
                 'CA', 'CH', 'CL', 'CM', 'CN', 'CO', 'CR', 'CS', 'CY', 'CZ', 'DE', 'DK', 'DZ', 'EC', 'EE', 'EG', 'ES', 'ET',
                 'FI', 'FJ', 'FO', 'FR', 'GB', 'GE', 'GI', 'GR', 'GT', 'GY', 'HK', 'HN', 'HR', 'HU', 'IE', 'IL',
                 'IN', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KH', 'KR', 'KW', 'KZ', 'LI', 'LT', 'LU', 'LV', 'MA',
                 'MD', 'MK', 'MO', 'MT', 'MX', 'MY', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PL', 'PS', 'PT', 'PY', 'QA',
                 'RO', 'RU', 'RW', 'SA', 'SE', 'SG', 'SI', 'SK', 'SM', 'SV', 'TH', 'TN', 'TR', 'UA', 'US', 'UY',
                 'UZ', 'VE', 'VG', 'VN', 'ZA']

# %%
# first use match_odds to get the event ids for each country individually
market_catalogue = []
for c in tqdm_notebook(all_countries):
    
    event_type_id = '["1"]'
    countries = '["'+c+'"]'
    market_types = '["MATCH_ODDS"]'
    market_start_time = (datetime.datetime.now() + datetime.timedelta(hours=-1)).strftime('%Y-%m-%dT%H:%M:%SZ')
    market_end_time = (datetime.datetime.now() + datetime.timedelta(hours=24)).strftime('%Y-%m-%dT%H:%M:%SZ')
    max_results = str(200)
    sort_type = 'FIRST_TO_START'
    metadata = '["EVENT"]' #, "RUNNER_METADATA"]'
    inplay = 'false'

    user_req='{"jsonrpc": "2.0", "method": "SportsAPING/v1.0/listMarketCatalogue",\
               "params": {"filter":{"eventTypeIds":'+event_type_id+',"marketTypeCodes":'+market_types+',\
               "inPlayOnly":'+inplay+', "marketCountries":'+countries+',  \
               "marketStartTime":{"from":"'+market_start_time+'", "to":"'+market_end_time+'"}},\
               "sort":"'+sort_type+'", "maxResults":"'+max_results+'", "marketProjection":'+metadata+'}, "id": 1}'

    request = requests.post(bet_url, data=user_req.encode('utf-8'), headers=headers)
    market_catalogue += request.json()['result']
# Out:
# HBox(children=(IntProgress(value=0, max=109), HTML(value='')))

# %%
all_event_ids = list(set([m.get('event', {}).get('id') for m in market_catalogue if m.get('event', {}).get('id', 'na')!='na']))

# %%
len(all_event_ids)
# Out:
# 180

# %% [markdown]
# #### Now get required markets for each event

# %%
market_catalogue = []
for e in tqdm_notebook(all_event_ids): # Note: these event ids are the football matches, as opposed to event_type_id 1 which means football
    
    event_type_id = '["1"]'
    #countries = '["GB", "FR", "IT", "DE", "ES"]'
    match_event_id = '["'+e+'"]'
    market_types = '["CORRECT_SCORE", "MATCH_ODDS", "OVER_UNDER_05", "OVER_UNDER_15", "OVER_UNDER_25", "OVER_UNDER_35", "OVER_UNDER_45"]'
    market_start_time = (datetime.datetime.now() + datetime.timedelta(hours=-1)).strftime('%Y-%m-%dT%H:%M:%SZ')
    market_end_time = (datetime.datetime.now() + datetime.timedelta(hours=24)).strftime('%Y-%m-%dT%H:%M:%SZ')
    max_results = str(200)
    sort_type = 'FIRST_TO_START'
    metadata = '["EVENT_TYPE", "COMPETITION", "EVENT", "MARKET_START_TIME", "MARKET_DESCRIPTION", "RUNNER_DESCRIPTION"]' #, "RUNNER_METADATA"]'
    inplay = 'false'

    user_req='{"jsonrpc": "2.0", "method": "SportsAPING/v1.0/listMarketCatalogue",\
               "params": {"filter":{"eventTypeIds":'+event_type_id+',"marketTypeCodes":'+market_types+',\
               "inPlayOnly":'+inplay+', "eventIds":'+match_event_id+',  \
               "marketStartTime":{"from":"'+market_start_time+'", "to":"'+market_end_time+'"}},\
               "sort":"'+sort_type+'", "maxResults":"'+max_results+'", "marketProjection":'+metadata+'}, "id": 1}'

    request = requests.post(bet_url, data=user_req.encode('utf-8'), headers=headers)
    market_catalogue += request.json()['result']
# Out:
# HBox(children=(IntProgress(value=0, max=180), HTML(value='')))

# %%
market_info_time_utc = datetime.datetime.utcnow()

# %%
market_info_time_utc
# Out:
# datetime.datetime(2021, 6, 18, 10, 39, 25, 527148)

# %% [markdown]
# ## Parse market details

# %%
def parse_market_details(market_cat_entry):
    
    description = market_cat_entry.get('description', {})
    event = market_cat_entry.get('event', {})
    event_type = market_cat_entry.get('eventType', {})
    competition = market_cat_entry.get('competition', {})
    
    return [
        market_cat_entry.get('marketId', None),
        market_cat_entry.get('marketStartTime', None),
        description.get('bspMarket', None),
        description.get('turnInPlayEnabled', None),
        description.get('persistenceEnabled', None),
        description.get('marketBaseRate', None),
        event.get('id', None),
        event.get('name', None),
        competition.get('id', None),
        competition.get('name', None),
        event_type.get('id', None),
        description.get('raceType', None),
        description.get('bettingType', None),
        description.get('marketType', None),
        description.get('marketTime', None),
        description.get('suspendTime', None),
        description.get('bspReconciled', None),
        description.get('complete', None),
        description.get('inPlay', None),
        str(description.get('regulator', None)),
        event.get('venue', None),
        event.get('countryCode', None),
        description.get('discountAllowed', None),
        event.get('timezone', None),
        event.get('openDate', None),
        market_cat_entry.get('marketName', None)
    ]


def parse_runners(market_cat_entry):

    market_id = market_cat_entry.get('marketId', None)
    
    runners = market_cat_entry.get('runners', {})
    runners_list = []
    for r in runners:
        r_id = r.get('selectionId', None)
        r_name = r.get('runnerName', None)
        handicap = r.get('handicap', None)
        sort_priority = r.get('sortPriority', None)
        runners_list.append([r_id, r_name, handicap, sort_priority, market_id])
    
    return runners_list

md_cols = [
    'market_id',
    'market_start_time',
    'bsp_market',
    'in_play_enabled',
    'persistence_enabled',
    'market_base_rate',
    'event_id',
    'event_name',
    'competition_id',
    'competition_name',
    'event_type_id',
    'race_type',
    'betting_type',
    'market_type',
    'market_time',
    'suspend_time',
    'bsp_reconciled',
    'complete',
    'in_play',
    'regulator',
    'venue',
    'country_code',
    'discount_allowed',
    'timezone',
    'open_date',
    'market_name'
]

r_cols = ['runner_id', 'runner_name', 'handicap', 'sort_priority', 'market_id']

# %%
market_definitions = []
runners = []
for m in market_catalogue:
    market_definitions.append(parse_market_details(m))
    runners += parse_runners(m)
    
market_definitions_df = pd.DataFrame(market_definitions, columns=md_cols)
market_definitions_df['api_call_time_utc'] = market_info_time_utc
runners_df = pd.DataFrame(runners, columns=r_cols)
runners_df['api_call_time_utc'] = market_info_time_utc

# %%
# add time to event in order to select appropriate model
market_definitions_df['minutes_to_event'] = (
    pd.to_datetime(market_definitions_df['market_time']) - pd.to_datetime(market_definitions_df['api_call_time_utc'], utc=True)).dt.seconds/60

# %%
len(market_definitions_df)
# Out:
# 1124

# %%
# subset to only events that have all markets
event_markets = market_definitions_df.groupby(['event_id', 'market_type']).head(1).groupby('event_id').size().reset_index().rename(columns={0: 'number_markets'})
event_markets_complete = event_markets[event_markets['number_markets']>=7]

# %%
market_definitions_df = market_definitions_df[market_definitions_df['event_id'].isin(event_markets_complete['event_id'])]

# %%
len(market_definitions_df)
# Out:
# 308

# %%
runners_df = runners_df[runners_df['market_id'].isin(market_definitions_df['market_id'])]

# %%
len(runners_df)
# Out:
# 1408

# %% [markdown]
# ## Get odds for markets

# %% [markdown]
# #### Get and view markets

# %%
markets = list(market_definitions_df['market_id'].unique())

# %%
market_books = []
for m in tqdm_notebook(markets):
    
    priceProjection = '["EX_BEST_OFFERS"]'
    prices_req = '{"jsonrpc": "2.0", "method": "SportsAPING/v1.0/listMarketBook", "params": {"marketIds": ["' + m + '"],"priceProjection":{"priceData":["EX_BEST_OFFERS"]}}, "id": 1}'
    request = requests.post(bet_url, data=prices_req.encode('utf-8'), headers=headers)
    prices_result = request.json()
    
    market_books.append(prices_result['result'][0])
# Out:
# HBox(children=(IntProgress(value=0, max=308), HTML(value='')))

# %%
def parse_market_book(market_book):
    
    return [
        market_book.get('marketId', None),
        market_book.get('isMarketDataDelayed', None),
        market_book.get('status', None),
        market_book.get('betDelay', None),
        market_book.get('bspReconciled', None),
        market_book.get('complete', None),
        market_book.get('inplay', None),
        market_book.get('numberOfWinners', None),
        market_book.get('numberOfRunners', None),
        market_book.get('numberOfActiveRunners', None),
        market_book.get('lastMatchTime', None),
        market_book.get('totalMatched', None),
        market_book.get('totalAvailable', None),
        market_book.get('crossMatching', None),
        market_book.get('runnersVoidable', None),
        market_book.get('version', None)
    ]

def parse_market_odds(market_book):
    
    market_id = market_book.get('marketId', None)
    
    runners = market_book.get('runners', {})
    runners_list = []
    for r in runners:
        r_id = r.get('selectionId', None)
        handicap = r.get('handicap', None)
        status = r.get('status', None)
        ltp = r.get('lastPriceTraded', None)
        total_matched = r.get('totalMatched', None)
        
        ex_back = r.get('ex', {}).get('availableToBack', [])
        back_prices = [None, None, None]
        back_sizes = [None, None, None]
        for i, b in enumerate(ex_back[:3]):
            back_prices[i] = b.get('price', None)
            back_sizes[i] = b.get('size', None)
        
        ex_lay = r.get('ex', {}).get('availableToLay', [])
        lay_prices = [None, None, None]
        lay_sizes = [None, None, None]
        for i, l in enumerate(ex_lay[:3]):
            lay_prices[i] = l.get('price', None)
            lay_sizes[i] = l.get('size', None)
        
        runners_list.append([r_id, handicap, status, ltp, total_matched] + back_prices + back_sizes + lay_prices + lay_sizes + [market_id])    
    
    return runners_list

mb_cols = [
    'market_id',
    'is_market_data_delayed',
    'market_status',
    'bet_delay',
    'bsp_reconciled',
    'complete',
    'inplay',
    'number_of_winners',
    'number_of_runners',
    'number_of_active_runners',
    'last_match_time',
    'total_matched',
    'total_available',
    'cross_matching',
    'runners_voidable',
    'version'
]

odds_cols = [
    'runner_id', 'handicap', 'status', 'ltp', 'total_matched',
    'back_price_1', 'back_price_2', 'back_price_3', 'back_size_1', 'back_size_2', 'back_size_3',
    'lay_price_1', 'lay_price_2', 'lay_price_3', 'lay_size_1', 'lay_size_2', 'lay_size_3',
    'market_id'
]

# %%
market_books_lists = []
market_odds_lists = []
for m in market_books:
    market_books_lists.append(parse_market_book(m))
    market_odds_lists += parse_market_odds(m)

# %%
market_books_df = pd.DataFrame(market_books_lists, columns=mb_cols)
market_odds_df = pd.DataFrame(market_odds_lists, columns=odds_cols)

# %% [markdown]
# ## Get into prediction data

# %%
# in particular the event details from market definitions and the number of places from the market book

market_definition_columns = [
    'market_id', 'market_start_time', 'market_time', 'suspend_time', 'open_date', 'api_call_time_utc', 'minutes_to_event',
    'event_id', 'venue', 'event_name', 'competition_id', 'competition_name', 'race_type', 'market_name', 'market_type', 'event_type_id', 'betting_type', 'country_code', 'timezone',
    'bsp_market', 'in_play_enabled', 'persistence_enabled', 'market_base_rate', 'regulator', 'discount_allowed'
]

market_book_columns = [
    'market_id', 'number_of_winners', 'number_of_runners', 'number_of_active_runners',
    'last_match_time', 'total_matched', 'total_available', 'cross_matching', 'runners_voidable', 'version',
    'is_market_data_delayed', 'market_status', 'bet_delay', 'bsp_reconciled', 'complete', 'inplay'
]

md_len_check = len(market_definitions_df)
mb_len_check = len(market_definitions_df)

market_details_combined = market_definitions_df[market_definition_columns].merge(market_books_df[market_book_columns], how='left', on='market_id')

if md_len_check!=len(market_details_combined):
    raise StopIteration('Duplicate markets!')

if mb_len_check!=len(market_details_combined):
    raise StopIteration('Potentially missing some market details!')

# %% [markdown]
# #### Combine runners and odds data

# %%
market_odds_df.head(3)
# Out:
#    runner_id  handicap  status  ltp  total_matched  back_price_1  \
# 0          1       0.0  ACTIVE  NaN            0.0           8.0
# 1          4       0.0  ACTIVE  NaN            0.0          13.5
# 2          9       0.0  ACTIVE  NaN            0.0          30.0
#
#    back_price_2  back_price_3  back_size_1  back_size_2  back_size_3  \
# 0          2.74          1.01        15.14        25.14        10.14
# 1          2.40          1.01        14.37        27.66        10.54
# 2          2.62          1.01        14.16        25.11        10.35
#
#    lay_price_1  lay_price_2  lay_price_3  lay_size_1  lay_size_2  lay_size_3  \
# 0          NaN          NaN          NaN         NaN         NaN         NaN
# 1         19.0          NaN          NaN        4.18         NaN         NaN
# 2          NaN          NaN          NaN         NaN         NaN         NaN
#
#      market_id
# 0  1.184561503
# 1  1.184561503
# 2  1.184561503

# %%
runner_cols = [
    'runner_id', 'runner_name', 'market_id', 'sort_priority', 'api_call_time_utc'
]

market_odds_cols = [
    'runner_id', 'handicap', 'status', 'market_id', 'ltp', 'total_matched',
    'back_price_1', 'back_price_2', 'back_price_3', 'back_size_1', 'back_size_2', 'back_size_3',
    'lay_price_1', 'lay_price_2', 'lay_price_3', 'lay_size_1', 'lay_size_2', 'lay_size_3'
]

runner_len_check = len(runners_df)
odds_len_check = len(market_odds_df)

runners_and_odds = runners_df[runner_cols].merge(market_odds_df[market_odds_cols], how='left', on=['runner_id', 'market_id'])

if runner_len_check!=len(runners_and_odds):
    raise StopIteration('Duplicate runners!')
    
if odds_len_check!=len(runners_and_odds):
    raise StopIteration('Potentially missing runner or odds details!')

# %%
combined_data = market_details_combined.merge(runners_and_odds.drop(columns='api_call_time_utc'), how='left', on='market_id', suffixes=('_market', '_runner'))

# %%
home_mask = [str(r)==str(n)[:len(r)] for r, n in zip(combined_data['runner_name'], combined_data['event_name'])]
away_mask = [str(r)==str(n)[-len(r):] for r, n in zip(combined_data['runner_name'], combined_data['event_name'])]
combined_data['runner_name_general'] = combined_data['runner_name']
combined_data.loc[home_mask, 'runner_name_general'] = 'Home'
combined_data.loc[away_mask, 'runner_name_general'] = 'Away'

combined_data['market_runner'] = combined_data['market_type'] + ' ' + combined_data['runner_name_general']

# %%
combined_data.head(3)
# Out:
#      market_id         market_start_time               market_time  \
# 0  1.184561503  2021-06-18T16:30:00.000Z  2021-06-18T16:30:00.000Z
# 1  1.184561503  2021-06-18T16:30:00.000Z  2021-06-18T16:30:00.000Z
# 2  1.184561503  2021-06-18T16:30:00.000Z  2021-06-18T16:30:00.000Z
#
#                suspend_time                 open_date  \
# 0  2021-06-18T16:30:00.000Z  2021-06-18T16:30:00.000Z
# 1  2021-06-18T16:30:00.000Z  2021-06-18T16:30:00.000Z
# 2  2021-06-18T16:30:00.000Z  2021-06-18T16:30:00.000Z
#
#            api_call_time_utc  minutes_to_event  event_id venue  \
# 0 2021-06-18 10:39:25.527148        350.566667  30627350  None
# 1 2021-06-18 10:39:25.527148        350.566667  30627350  None
# 2 2021-06-18 10:39:25.527148        350.566667  30627350  None
#
#                   event_name competition_id        competition_name race_type  \
# 0  Dinamo Batumi v Dila Gori        2273834  Georgian Umaglesi Liga      None
# 1  Dinamo Batumi v Dila Gori        2273834  Georgian Umaglesi Liga      None
# 2  Dinamo Batumi v Dila Gori        2273834  Georgian Umaglesi Liga      None
#
#      market_name    market_type event_type_id betting_type country_code  \
# 0  Correct Score  CORRECT_SCORE             1         ODDS           GE
# 1  Correct Score  CORRECT_SCORE             1         ODDS           GE
# 2  Correct Score  CORRECT_SCORE             1         ODDS           GE
#
#   timezone  bsp_market  in_play_enabled  persistence_enabled  \
# 0      GMT       False             True                 True
# 1      GMT       False             True                 True
# 2      GMT       False             True                 True
#
#    market_base_rate            regulator  discount_allowed  number_of_winners  \
# 0               5.0  GIBRALTAR REGULATOR             False                  1
# 1               5.0  GIBRALTAR REGULATOR             False                  1
# 2               5.0  GIBRALTAR REGULATOR             False                  1
#
#    number_of_runners  number_of_active_runners last_match_time  \
# 0                 19                        19            None
# 1                 19                        19            None
# 2                 19                        19            None
#
#    total_matched_market  total_available  cross_matching  runners_voidable  \
# 0                   0.0          1014.71            True             False
# 1                   0.0          1014.71            True             False
# 2                   0.0          1014.71            True             False
#
#       version  is_market_data_delayed market_status  bet_delay  \
# 0  3873879624                    True          OPEN          0
# 1  3873879624                    True          OPEN          0
# 2  3873879624                    True          OPEN          0
#
#    bsp_reconciled  complete  inplay  runner_id runner_name  sort_priority  \
# 0           False      True   False          1       0 - 0              1
# 1           False      True   False          4       0 - 1              2
# 2           False      True   False          9       0 - 2              3
#
#    handicap  status  ltp  total_matched_runner  back_price_1  back_price_2  \
# 0       0.0  ACTIVE  NaN                   0.0           8.0          2.74
# 1       0.0  ACTIVE  NaN                   0.0          13.5          2.40
# 2       0.0  ACTIVE  NaN                   0.0          30.0          2.62
#
#    back_price_3  back_size_1  back_size_2  back_size_3  lay_price_1  \
# 0          1.01        15.14        25.14        10.14          NaN
# 1          1.01        14.37        27.66        10.54         19.0
# 2          1.01        14.16        25.11        10.35          NaN
#
#    lay_price_2  lay_price_3  lay_size_1  lay_size_2  lay_size_3  \
# 0          NaN          NaN         NaN         NaN         NaN
# 1          NaN          NaN        4.18         NaN         NaN
# 2          NaN          NaN         NaN         NaN         NaN
#
#   runner_name_general        market_runner
# 0               0 - 0  CORRECT_SCORE 0 - 0
# 1               0 - 1  CORRECT_SCORE 0 - 1
# 2               0 - 2  CORRECT_SCORE 0 - 2

# %%
per_event_data = combined_data.pivot_table(
    values=['back_price_1', 'market_id', 'runner_id', 'runner_name'], index=['event_id', 'event_name'], columns='market_runner', aggfunc=max, fill_value=None)
per_event_data.columns = [c[1]+' - '+c[0] for c in per_event_data.columns]
per_event_data.columns = [c.replace('back_price_1', 'ltp') for c in per_event_data.columns]
per_event_data = per_event_data.reset_index()

# %%
select_markets = [
    'CORRECT_SCORE 0 - 0 - ltp', 'CORRECT_SCORE 0 - 1 - ltp',
    'CORRECT_SCORE 0 - 2 - ltp', 'CORRECT_SCORE 0 - 3 - ltp',
    'CORRECT_SCORE 1 - 0 - ltp', 'CORRECT_SCORE 1 - 1 - ltp',
    'CORRECT_SCORE 1 - 2 - ltp', 'CORRECT_SCORE 1 - 3 - ltp',
    'CORRECT_SCORE 2 - 0 - ltp', 'CORRECT_SCORE 2 - 1 - ltp',
    'CORRECT_SCORE 2 - 2 - ltp', 'CORRECT_SCORE 2 - 3 - ltp',
    'CORRECT_SCORE 3 - 0 - ltp', 'CORRECT_SCORE 3 - 1 - ltp',
    'CORRECT_SCORE 3 - 2 - ltp', 'CORRECT_SCORE 3 - 3 - ltp',
    'MATCH_ODDS Away - ltp', 'MATCH_ODDS Home - ltp', 'MATCH_ODDS The Draw - ltp',
    'OVER_UNDER_05 Over 0.5 Goals - ltp', 'OVER_UNDER_05 Under 0.5 Goals - ltp',
    'OVER_UNDER_15 Over 1.5 Goals - ltp', 'OVER_UNDER_15 Under 1.5 Goals - ltp',
    'OVER_UNDER_25 Over 2.5 Goals - ltp', 'OVER_UNDER_25 Under 2.5 Goals - ltp',
    'OVER_UNDER_35 Over 3.5 Goals - ltp', 'OVER_UNDER_35 Under 3.5 Goals - ltp',
    'OVER_UNDER_45 Over 4.5 Goals - ltp', 'OVER_UNDER_45 Under 4.5 Goals - ltp'
]

# %%
per_event_data_complete = per_event_data[per_event_data[select_markets].isnull().sum(axis=1)==0]

# %%
pred_df = per_event_data_complete.copy()
minutes_to_event_min = combined_data.groupby('event_id')['minutes_to_event'].min().reset_index()
pred_df = pred_df.merge(minutes_to_event_min, how='left', on='event_id')

# %%
len(pred_df)
# Out:
# 44

# %% [markdown]
# ## Do preds

# %%
for o in select_markets:
    outcome = o.replace(' - ltp', ' - win')
    pred_col = o.replace(' - ltp', ' - pred')
    pred_odds_col = pred_col+'_odds'
    model = football_models[outcome]['model']
    features = football_models[outcome]['features']
    
    pred_X = pred_df[features]
    pred_X.insert(loc=0, column='const', value=1)
    
    pred_df[pred_col] = model.predict(pred_X)
    print(o+' first pred: '+str(pred_df[pred_col].iloc[0]))
    pred_df[pred_odds_col] = 1/pred_df[pred_col]
# Out:
# CORRECT_SCORE 0 - 0 - ltp first pred: 0.0963395454817371
# CORRECT_SCORE 0 - 1 - ltp first pred: 0.09171303974278454
# CORRECT_SCORE 0 - 2 - ltp first pred: 0.05123314239530223
# CORRECT_SCORE 0 - 3 - ltp first pred: 0.019903607528441104
# CORRECT_SCORE 1 - 0 - ltp first pred: 0.11944579494676756
# CORRECT_SCORE 1 - 1 - ltp first pred: 0.14557811204980117
# CORRECT_SCORE 1 - 2 - ltp first pred: 0.07509841156053343
# CORRECT_SCORE 1 - 3 - ltp first pred: 0.02184450531369086
# CORRECT_SCORE 2 - 0 - ltp first pred: 0.07873549681220703
# CORRECT_SCORE 2 - 1 - ltp first pred: 0.08987975767428937
# CORRECT_SCORE 2 - 2 - ltp first pred: 0.05220642435019664
# CORRECT_SCORE 2 - 3 - ltp first pred: 0.015894763677601478
# CORRECT_SCORE 3 - 0 - ltp first pred: 0.03534649945650223
# CORRECT_SCORE 3 - 1 - ltp first pred: 0.032389618697647046
# CORRECT_SCORE 3 - 2 - ltp first pred: 0.022439672079156602
# CORRECT_SCORE 3 - 3 - ltp first pred: 0.006298821467353425
# MATCH_ODDS Away - ltp first pred: 0.29495168830591034
# MATCH_ODDS Home - ltp first pred: 0.4072597974924505
# MATCH_ODDS The Draw - ltp first pred: 0.29827401168320783
# OVER_UNDER_05 Over 0.5 Goals - ltp first pred: 0.8984865350640382
# OVER_UNDER_05 Under 0.5 Goals - ltp first pred: 0.0963395454817371
# OVER_UNDER_15 Over 1.5 Goals - ltp first pred: 0.6899535056317263
# OVER_UNDER_15 Under 1.5 Goals - ltp first pred: 0.3062196211924995
# OVER_UNDER_25 Over 2.5 Goals - ltp first pred: 0.4201197924510754
# OVER_UNDER_25 Under 2.5 Goals - ltp first pred: 0.5745909350840638
# OVER_UNDER_35 Over 3.5 Goals - ltp first pred: 0.21019630509297452
# OVER_UNDER_35 Under 3.5 Goals - ltp first pred: 0.7846819753065299
# OVER_UNDER_45 Over 4.5 Goals - ltp first pred: 0.0918666624192563
# OVER_UNDER_45 Under 4.5 Goals - ltp first pred: 0.9021940244816029

# %%
odds_margin_mult = 1.5
min_odds = 0
max_odds = 100

for o in select_markets: # NOTE: in pred_df the 'ltp' prices are actually the back price 1 prices
    outcome = o.replace(' - ltp', ' - win')
    pred_col = o.replace(' - ltp', ' - pred')
    pred_odds_col = pred_col+'_odds'
    bet_col = o.replace(' - ltp', ' - bet')
    
    pred_df[bet_col] = ((pred_df[o]>pred_df[pred_odds_col]*odds_margin_mult) & (pred_df[o].between(min_odds, max_odds)))*1

# %%
pd.options.display.max_columns = 200

# %%
bet_cols = [str(s).replace(' - ltp', ' - bet') for s in select_markets]
pred_odds_cols = [str(s).replace(' - ltp', ' - pred_odds') for s in select_markets]
pred_df[bet_cols].sum()
# Out:
# CORRECT_SCORE 0 - 0 - bet              0
# CORRECT_SCORE 0 - 1 - bet              0
# CORRECT_SCORE 0 - 2 - bet              0
# CORRECT_SCORE 0 - 3 - bet              1
# CORRECT_SCORE 1 - 0 - bet              0
# CORRECT_SCORE 1 - 1 - bet              0
# CORRECT_SCORE 1 - 2 - bet              0
# CORRECT_SCORE 1 - 3 - bet              0
# CORRECT_SCORE 2 - 0 - bet              0
# CORRECT_SCORE 2 - 1 - bet              0
# CORRECT_SCORE 2 - 2 - bet              1
# CORRECT_SCORE 2 - 3 - bet              9
# CORRECT_SCORE 3 - 0 - bet              0
# CORRECT_SCORE 3 - 1 - bet              0
# CORRECT_SCORE 3 - 2 - bet              4
# CORRECT_SCORE 3 - 3 - bet              0
# MATCH_ODDS Away - bet                  0
# MATCH_ODDS Home - bet                  0
# MATCH_ODDS The Draw - bet              0
# OVER_UNDER_05 Over 0.5 Goals - bet     0
# OVER_UNDER_05 Under 0.5 Goals - bet    0
# OVER_UNDER_15 Over 1.5 Goals - bet     0
# OVER_UNDER_15 Under 1.5 Goals - bet    0
# OVER_UNDER_25 Over 2.5 Goals - bet     0
# OVER_UNDER_25 Under 2.5 Goals - bet    0
# OVER_UNDER_35 Over 3.5 Goals - bet     0
# OVER_UNDER_35 Under 3.5 Goals - bet    0
# OVER_UNDER_45 Over 4.5 Goals - bet     0
# OVER_UNDER_45 Under 4.5 Goals - bet    0
# dtype: int64

# %%
for o in select_markets:
    pred_df[o.replace(' - ltp', ' - bookie_probs')] = 1/pred_df[o]

bookie_prob_cols = [c for c in pred_df.columns if 'bookie_probs' in c]
correct_score_prob_cols = [c for c in bookie_prob_cols if 'CORRECT_SCORE' in c]
match_odds_prob_cols = [c for c in bookie_prob_cols if 'MATCH_ODDS' in c]
over_under_prob_cols = [c for c in bookie_prob_cols if 'OVER_UNDER' in c]
pred_df['correct_score_overround'] = pred_df[correct_score_prob_cols].sum(axis=1)
pred_df['match_odds_overround'] = pred_df[match_odds_prob_cols].sum(axis=1)
pred_df['over_under_overround'] = pred_df[over_under_prob_cols].sum(axis=1)

# %%
pred_df['correct_score_overround'].hist()

# %%
pred_df_long = []
for o in select_markets:
    market_runner = o.replace(' - ltp', '')
    market_id_col = o.replace(' - ltp', ' - market_id')
    pred_col = o.replace(' - ltp', ' - pred')
    pred_odds_col = o.replace(' - ltp', ' - pred_odds')
    bets_col = o.replace(' - ltp', ' - bet')
    
    tmp_df = pred_df[[o, market_id_col, pred_col, pred_odds_col, bets_col, 'correct_score_overround', 'match_odds_overround', 'over_under_overround']]
    tmp_df.columns = ['input_odds', 'market_id', 'pred', 'pred_odds', 'bet', 'correct_score_overround', 'match_odds_overround', 'over_under_overround']
    tmp_df['market_runner'] = market_runner
    pred_df_long.append(tmp_df)

pred_df_long = pd.concat(pred_df_long, axis=0)

# %%
output_df = combined_data.merge(pred_df_long, how='left', on=['market_id', 'market_runner'])

# %%
# redo bets
odds_margin_mult = 1.25
min_odds = 0
max_odds = 30
max_overround_cs = 1.03
max_overround_mo = 1.05
max_mins_to_event = 600

output_df['bet'] = (
    (output_df['back_price_1']>=output_df['pred_odds']*odds_margin_mult) &
    (output_df['back_price_1'].between(min_odds, max_odds)) &
    (output_df['correct_score_overround']<=max_overround_cs) & 
    (output_df['match_odds_overround']<=max_overround_mo) &
    (output_df['minutes_to_event']<=max_mins_to_event) &
    ~((output_df['market_id'].astype(str)+output_df['runner_id'].astype(str)).isin((existing_back_bets['market_id'].astype(str)+existing_back_bets['runner_id'].astype(str))))
)*1

# WANT TO STOP BETS BEING PLACED ON BOTH 0-0 AND UNDER 0.5 GOALS HERE?

# %%
cols_to_view = ['market_start_time', 'minutes_to_event', 'event_name', 'competition_name', 'market_name', 'market_type', 'runner_name',
                'ltp', 'back_price_1', 'lay_price_1', 'runner_name_general', 'market_runner', 'input_odds', 'pred', 'pred_odds', 'correct_score_overround', 'match_odds_overround', 'over_under_overround']
output_df.loc[output_df['bet']==1, cols_to_view]
# Out:
#              market_start_time  minutes_to_event                   event_name  \
# 149   2021-06-18T18:45:00.000Z        485.566667      Galway Utd v Cabinteely
# 1041  2021-06-18T19:15:00.000Z        515.566667        Afturelding v Selfoss
# 1053  2021-06-18T19:15:00.000Z        515.566667        Afturelding v Selfoss
# 1075  2021-06-18T18:00:00.000Z        440.566667            Thor v Kordrengir
# 1326  2021-06-18T15:00:00.000Z        260.566667  Slutsk v Shakhter Soligorsk
#
#                competition_name    market_name    market_type  runner_name  \
# 149            Irish Division 1  Correct Score  CORRECT_SCORE        3 - 2
# 1041          Icelandic 1 Deild  Correct Score  CORRECT_SCORE        3 - 1
# 1053          Icelandic 1 Deild     Match Odds     MATCH_ODDS  Afturelding
# 1075          Icelandic 1 Deild  Correct Score  CORRECT_SCORE        3 - 2
# 1326  Belarusian Premier League  Correct Score  CORRECT_SCORE        2 - 2
#
#        ltp  back_price_1  lay_price_1 runner_name_general  \
# 149    NaN         28.00        36.00               3 - 2
# 1041   NaN         21.00        27.00               3 - 1
# 1053   2.9          2.84         3.05                Home
# 1075   NaN         22.00        27.00               3 - 2
# 1326  30.0         27.00        32.00               2 - 2
#
#             market_runner  input_odds      pred  pred_odds  \
# 149   CORRECT_SCORE 3 - 2       28.00  0.056185  17.798305
# 1041  CORRECT_SCORE 3 - 1       21.00  0.063582  15.727799
# 1053      MATCH_ODDS Home        2.84  0.471202   2.122232
# 1075  CORRECT_SCORE 3 - 2       22.00  0.060071  16.647056
# 1326  CORRECT_SCORE 2 - 2       27.00  0.056588  17.671732
#
#       correct_score_overround  match_odds_overround  over_under_overround
# 149                  0.947813              1.028968              5.322000
# 1041                 0.867085              1.014168              5.549701
# 1053                 0.867085              1.014168              5.549701
# 1075                 0.886632              1.025194              5.352799
# 1326                 0.975346              1.021523              5.326977

# %% [markdown]
# #### Get distribution of outcomes

# %%
potential_winnings = 2*output_df.loc[output_df['bet']==1, 'back_price_1']
probs_me = output_df.loc[output_df['bet']==1, 'pred']
probs_bookie_adj = (1/output_df.loc[output_df['bet']==1, 'back_price_1'])/1.03
samples = 10000
outcomes_me = [sum(np.random.binomial(1, probs_me)*potential_winnings)-len(probs_me)*2 for i in range(samples)]
outcomes_bookie = [sum(np.random.binomial(1, probs_bookie_adj)*potential_winnings)-len(probs_bookie_adj)*2 for i in range(samples)]

# %%
probs_me
# Out:
# 149     0.056185
# 1041    0.063582
# 1053    0.471202
# 1075    0.060071
# 1326    0.056588
# Name: pred, dtype: float64

# %%
probs_bookie_adj
# Out:
# 149     0.034674
# 1041    0.046232
# 1053    0.341857
# 1075    0.044131
# 1326    0.035958
# Name: back_price_1, dtype: float64

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 7))

sns.distplot(outcomes_me, ax=ax[0]).set_title('My Probs Outcome Dist')
ax[0].set(ylim=(0, 0.7))
sns.distplot(outcomes_bookie, ax=ax[1]).set_title('Bookie Probs Outcome Dist')
ax[1].set(ylim=(0, 0.7))
# Out:
# [(0, 0.7)]

# %%
np.mean(outcomes_me)
# Out:
# 4.249456

# %%
sum(np.array(outcomes_me)<0)/len(outcomes_me)
# Out:
# 0.7789

# %%
np.mean(outcomes_bookie)
# Out:
# -0.4271119999999997

# %%
sum(np.array(outcomes_bookie)<0)/len(outcomes_bookie)
# Out:
# 0.8503

# %%
output_df[
    (output_df['back_price_1'].between(min_odds, max_odds)) &
    (output_df['correct_score_overround']<=max_overround_cs) & 
    (output_df['match_odds_overround']<=max_overround_mo) &
    (output_df['minutes_to_event']<=max_mins_to_event)]
# Out:
#         market_id         market_start_time               market_time  \
# 64    1.184467423  2021-06-18T18:45:00.000Z  2021-06-18T18:45:00.000Z
# 65    1.184467423  2021-06-18T18:45:00.000Z  2021-06-18T18:45:00.000Z
# 66    1.184467428  2021-06-18T18:45:00.000Z  2021-06-18T18:45:00.000Z
# 67    1.184467428  2021-06-18T18:45:00.000Z  2021-06-18T18:45:00.000Z
# 68    1.184467428  2021-06-18T18:45:00.000Z  2021-06-18T18:45:00.000Z
# ...           ...                       ...                       ...
# 1394  1.184452588  2021-06-18T18:45:00.000Z  2021-06-18T18:45:00.000Z
# 1395  1.184452588  2021-06-18T18:45:00.000Z  2021-06-18T18:45:00.000Z
# 1396  1.184452588  2021-06-18T18:45:00.000Z  2021-06-18T18:45:00.000Z
# 1399  1.184452588  2021-06-18T18:45:00.000Z  2021-06-18T18:45:00.000Z
# 1403  1.184452588  2021-06-18T18:45:00.000Z  2021-06-18T18:45:00.000Z
#
#                   suspend_time                 open_date  \
# 64    2021-06-18T18:45:00.000Z  2021-06-18T18:45:00.000Z
# 65    2021-06-18T18:45:00.000Z  2021-06-18T18:45:00.000Z
# 66    2021-06-18T18:45:00.000Z  2021-06-18T18:45:00.000Z
# 67    2021-06-18T18:45:00.000Z  2021-06-18T18:45:00.000Z
# 68    2021-06-18T18:45:00.000Z  2021-06-18T18:45:00.000Z
# ...                        ...                       ...
# 1394  2021-06-18T18:45:00.000Z  2021-06-18T18:45:00.000Z
# 1395  2021-06-18T18:45:00.000Z  2021-06-18T18:45:00.000Z
# 1396  2021-06-18T18:45:00.000Z  2021-06-18T18:45:00.000Z
# 1399  2021-06-18T18:45:00.000Z  2021-06-18T18:45:00.000Z
# 1403  2021-06-18T18:45:00.000Z  2021-06-18T18:45:00.000Z
#
#               api_call_time_utc  minutes_to_event  event_id venue  \
# 64   2021-06-18 10:39:25.527148        485.566667  30617291  None
# 65   2021-06-18 10:39:25.527148        485.566667  30617291  None
# 66   2021-06-18 10:39:25.527148        485.566667  30617291  None
# 67   2021-06-18 10:39:25.527148        485.566667  30617291  None
# 68   2021-06-18 10:39:25.527148        485.566667  30617291  None
# ...                         ...               ...       ...   ...
# 1394 2021-06-18 10:39:25.527148        485.566667  30616193  None
# 1395 2021-06-18 10:39:25.527148        485.566667  30616193  None
# 1396 2021-06-18 10:39:25.527148        485.566667  30616193  None
# 1399 2021-06-18 10:39:25.527148        485.566667  30616193  None
# 1403 2021-06-18 10:39:25.527148        485.566667  30616193  None
#
#                        event_name competition_id        competition_name  \
# 64       Wexford F.C v Shelbourne       12005855        Irish Division 1
# 65       Wexford F.C v Shelbourne       12005855        Irish Division 1
# 66       Wexford F.C v Shelbourne       12005855        Irish Division 1
# 67       Wexford F.C v Shelbourne       12005855        Irish Division 1
# 68       Wexford F.C v Shelbourne       12005855        Irish Division 1
# ...                           ...            ...                     ...
# 1394  Waterford v Shamrock Rovers       12203971  Irish Premier Division
# 1395  Waterford v Shamrock Rovers       12203971  Irish Premier Division
# 1396  Waterford v Shamrock Rovers       12203971  Irish Premier Division
# 1399  Waterford v Shamrock Rovers       12203971  Irish Premier Division
# 1403  Waterford v Shamrock Rovers       12203971  Irish Premier Division
#
#      race_type           market_name    market_type event_type_id  \
# 64        None  Over/Under 0.5 Goals  OVER_UNDER_05             1
# 65        None  Over/Under 0.5 Goals  OVER_UNDER_05             1
# 66        None         Correct Score  CORRECT_SCORE             1
# 67        None         Correct Score  CORRECT_SCORE             1
# 68        None         Correct Score  CORRECT_SCORE             1
# ...        ...                   ...            ...           ...
# 1394      None         Correct Score  CORRECT_SCORE             1
# 1395      None         Correct Score  CORRECT_SCORE             1
# 1396      None         Correct Score  CORRECT_SCORE             1
# 1399      None         Correct Score  CORRECT_SCORE             1
# 1403      None         Correct Score  CORRECT_SCORE             1
#
#      betting_type country_code timezone  bsp_market  in_play_enabled  \
# 64           ODDS           IE      GMT       False             True
# 65           ODDS           IE      GMT       False             True
# 66           ODDS           IE      GMT       False             True
# 67           ODDS           IE      GMT       False             True
# 68           ODDS           IE      GMT       False             True
# ...           ...          ...      ...         ...              ...
# 1394         ODDS           IE      GMT       False             True
# 1395         ODDS           IE      GMT       False             True
# 1396         ODDS           IE      GMT       False             True
# 1399         ODDS           IE      GMT       False             True
# 1403         ODDS           IE      GMT       False             True
#
#       persistence_enabled  market_base_rate            regulator  \
# 64                   True               5.0  GIBRALTAR REGULATOR
# 65                   True               5.0  GIBRALTAR REGULATOR
# 66                   True               5.0  GIBRALTAR REGULATOR
# 67                   True               5.0  GIBRALTAR REGULATOR
# 68                   True               5.0  GIBRALTAR REGULATOR
# ...                   ...               ...                  ...
# 1394                 True               5.0  GIBRALTAR REGULATOR
# 1395                 True               5.0  GIBRALTAR REGULATOR
# 1396                 True               5.0  GIBRALTAR REGULATOR
# 1399                 True               5.0  GIBRALTAR REGULATOR
# 1403                 True               5.0  GIBRALTAR REGULATOR
#
#       discount_allowed  number_of_winners  number_of_runners  \
# 64               False                  1                  2
# 65               False                  1                  2
# 66               False                  1                 19
# 67               False                  1                 19
# 68               False                  1                 19
# ...                ...                ...                ...
# 1394             False                  1                 19
# 1395             False                  1                 19
# 1396             False                  1                 19
# 1399             False                  1                 19
# 1403             False                  1                 19
#
#       number_of_active_runners           last_match_time  \
# 64                           2  2021-06-18T05:28:33.712Z
# 65                           2  2021-06-18T05:28:33.712Z
# 66                          19  2021-06-18T10:03:44.829Z
# 67                          19  2021-06-18T10:03:44.829Z
# 68                          19  2021-06-18T10:03:44.829Z
# ...                        ...                       ...
# 1394                        19  2021-06-18T10:22:10.790Z
# 1395                        19  2021-06-18T10:22:10.790Z
# 1396                        19  2021-06-18T10:22:10.790Z
# 1399                        19  2021-06-18T10:22:10.790Z
# 1403                        19  2021-06-18T10:22:10.790Z
#
#       total_matched_market  total_available  cross_matching  runners_voidable  \
# 64                    4.00           626.63            True             False
# 65                    4.00           626.63            True             False
# 66                   21.13          6078.10            True             False
# 67                   21.13          6078.10            True             False
# 68                   21.13          6078.10            True             False
# ...                    ...              ...             ...               ...
# 1394                337.79         98943.24            True             False
# 1395                337.79         98943.24            True             False
# 1396                337.79         98943.24            True             False
# 1399                337.79         98943.24            True             False
# 1403                337.79         98943.24            True             False
#
#          version  is_market_data_delayed market_status  bet_delay  \
# 64    3872185752                    True          OPEN          0
# 65    3872185752                    True          OPEN          0
# 66    3872185778                    True          OPEN          0
# 67    3872185778                    True          OPEN          0
# 68    3872185778                    True          OPEN          0
# ...          ...                     ...           ...        ...
# 1394  3872185465                    True          OPEN          0
# 1395  3872185465                    True          OPEN          0
# 1396  3872185465                    True          OPEN          0
# 1399  3872185465                    True          OPEN          0
# 1403  3872185465                    True          OPEN          0
#
#       bsp_reconciled  complete  inplay  runner_id      runner_name  \
# 64             False      True   False    5851482  Under 0.5 Goals
# 65             False      True   False    5851483   Over 0.5 Goals
# 66             False      True   False          1            0 - 0
# 67             False      True   False          4            0 - 1
# 68             False      True   False          9            0 - 2
# ...              ...       ...     ...        ...              ...
# 1394           False      True   False          3            1 - 1
# 1395           False      True   False          8            1 - 2
# 1396           False      True   False         15            1 - 3
# 1399           False      True   False          7            2 - 2
# 1403           False      True   False         12            3 - 2
#
#       sort_priority  handicap  status     ltp  total_matched_runner  \
# 64                1       0.0  ACTIVE     NaN                   0.0
# 65                2       0.0  ACTIVE    1.03                   0.0
# 66                1       0.0  ACTIVE   19.50                   0.0
# 67                2       0.0  ACTIVE     NaN                   0.0
# 68                3       0.0  ACTIVE     NaN                   0.0
# ...             ...       ...     ...     ...                   ...
# 1394              6       0.0  ACTIVE   12.00                   0.0
# 1395              7       0.0  ACTIVE   11.00                   0.0
# 1396              8       0.0  ACTIVE   13.50                   0.0
# 1399             11       0.0  ACTIVE   32.00                   0.0
# 1403             15       0.0  ACTIVE  170.00                   0.0
#
#       back_price_1  back_price_2  back_price_3  back_size_1  back_size_2  \
# 64            4.80          1.02          1.01        28.57       100.70
# 65            1.03          1.01           NaN       133.52       113.44
# 66           19.50         18.00          6.00        13.58        13.45
# 67            8.60          8.40          8.20        10.36        13.68
# 68            6.20          5.80          4.30        28.47        13.87
# ...            ...           ...           ...          ...          ...
# 1394         11.50         11.00          8.20        18.06        34.24
# 1395          9.80          9.40          7.00        26.08        35.70
# 1396         13.00         11.50          9.20        21.89        15.37
# 1399         29.00         14.00         12.50        17.36        12.20
# 1403         19.50         15.50         10.00        14.62        16.84
#
#       back_size_3  lay_price_1  lay_price_2  lay_price_3  lay_size_1  \
# 64         102.70       110.00          NaN          NaN        4.92
# 65            NaN         1.06         1.26        110.0       37.74
# 66          12.59        26.00          NaN          NaN       10.01
# 67          13.49         9.80       420.00          NaN       12.98
# 68          11.43         9.00        50.00          NaN       15.50
# ...           ...          ...          ...          ...         ...
# 1394        10.73        12.50        13.50         26.0       54.99
# 1395        21.90        10.50        11.50         16.0       42.69
# 1396        11.56        14.50        15.00         15.5       76.69
# 1399        11.39        32.00        36.00         80.0       13.77
# 1403        10.55       180.00          NaN          NaN       19.09
#
#       lay_size_2  lay_size_3 runner_name_general  \
# 64           NaN         NaN     Under 0.5 Goals
# 65        102.24        2.81      Over 0.5 Goals
# 66           NaN         NaN               0 - 0
# 67          5.10         NaN               0 - 1
# 68          4.73         NaN               0 - 2
# ...          ...         ...                 ...
# 1394       15.28       10.33               1 - 1
# 1395       16.24       11.50               1 - 2
# 1396       20.00       20.00               1 - 3
# 1399       12.53        3.41               2 - 2
# 1403         NaN         NaN               3 - 2
#
#                       market_runner  input_odds      pred  pred_odds  bet  \
# 64    OVER_UNDER_05 Under 0.5 Goals        4.80  0.023224  43.058404    0
# 65     OVER_UNDER_05 Over 0.5 Goals        1.03  0.959083   1.042663    0
# 66              CORRECT_SCORE 0 - 0       19.50  0.023224  43.058404    0
# 67              CORRECT_SCORE 0 - 1        8.60  0.066863  14.955865    0
# 68              CORRECT_SCORE 0 - 2        6.20  0.116031   8.618377    0
# ...                             ...         ...       ...        ...  ...
# 1394            CORRECT_SCORE 1 - 1       11.50  0.094611  10.569627    0
# 1395            CORRECT_SCORE 1 - 2        9.80  0.078453  12.746478    0
# 1396            CORRECT_SCORE 1 - 3       13.00  0.083947  11.912269    0
# 1399            CORRECT_SCORE 2 - 2       29.00  0.033230  30.093494    0
# 1403            CORRECT_SCORE 3 - 2       19.50  0.020160  49.602256    0
#
#       correct_score_overround  match_odds_overround  over_under_overround
# 64                   0.890614              1.024840               5.38789
# 65                   0.890614              1.024840               5.38789
# 66                   0.890614              1.024840               5.38789
# 67                   0.890614              1.024840               5.38789
# 68                   0.890614              1.024840               5.38789
# ...                       ...                   ...                   ...
# 1394                 0.922973              1.014787               5.13653
# 1395                 0.922973              1.014787               5.13653
# 1396                 0.922973              1.014787               5.13653
# 1399                 0.922973              1.014787               5.13653
# 1403                 0.922973              1.014787               5.13653
#
# [407 rows x 68 columns]

# %% [markdown]
# #### Dig deeper on predictions

# %%
plot_data = pred_df[(pred_df['correct_score_overround']<1.2) & (pred_df['match_odds_overround']<1.5) & (pred_df['minutes_to_event']<=600000)]

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 7))

sns.scatterplot(data=plot_data, x='MATCH_ODDS The Draw - ltp', y='MATCH_ODDS The Draw - pred_odds')
sns.lineplot(data=plot_data, x='MATCH_ODDS The Draw - ltp', y='MATCH_ODDS The Draw - ltp')

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 7))

sns.scatterplot(data=plot_data, x='MATCH_ODDS Away - ltp', y='MATCH_ODDS Away - pred_odds')
sns.lineplot(data=plot_data, x='MATCH_ODDS Away - ltp', y='MATCH_ODDS Away - ltp')

# %%
plot_data.to_csv('football_preds_test.csv', index=False)

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 7))

sns.scatterplot(data=plot_data, x='MATCH_ODDS Home - ltp', y='MATCH_ODDS Home - pred_odds')
sns.lineplot(data=plot_data, x='MATCH_ODDS Home - ltp', y='MATCH_ODDS Home - ltp')

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 7))

to_plot = 'CORRECT_SCORE 2 - 2'

sns.scatterplot(data=plot_data, x=to_plot+' - ltp', y=to_plot+' - pred_odds')
sns.lineplot(data=plot_data, x=to_plot+' - ltp', y=to_plot+' - ltp')

# %% [markdown]
# ## Place bets

# %%
breakhere
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-bffaabe7143d> in <module>
# ----> 1 breakhere
#
# NameError: name 'breakhere' is not defined

# %%
def parse_order_result(order_result):
    instruction_report = order_result.get('instructionReports', [{}])[0]
    instruction = instruction_report.get('instruction', {})
    limit_order = instruction.get('limitOrder', {})
    
    return [
        order_result.get('status', None),
        order_result.get('marketId', None),
        instruction.get('selectionId', None),
        instruction.get('handicap', None),
        limit_order.get('size', None),
        limit_order.get('price', None),
        limit_order.get('timeInForce', None),
        limit_order.get('minFillSize', None),
        instruction.get('orderType', None),
        instruction.get('side', None),
        instruction_report.get('errorCode', None),
        instruction_report.get('betId', None),
        instruction_report.get('placedDate', None),
        instruction_report.get('averagePriceMatched', None),
        instruction_report.get('sizeMatched', None),
        instruction_report.get('orderStatus', None)
    ]
    
order_cols = ['status', 'market_id', 'selection_id', 'handicap', 'size', 'price', 'time_in_force', 'min_fill_size',
              'order_type', 'side', 'error_code', 'bet_id', 'placed_date', 'average_price_matched', 'size_matched', 'order_status']

# %%
order_results = []
order_fails = []

# %%
back_bets = output_df[output_df['bet']==1]
back_bets
# Out:
#         market_id         market_start_time               market_time  \
# 149   1.184467158  2021-06-18T18:45:00.000Z  2021-06-18T18:45:00.000Z
# 1041  1.184452390  2021-06-18T19:15:00.000Z  2021-06-18T19:15:00.000Z
# 1053  1.184452381  2021-06-18T19:15:00.000Z  2021-06-18T19:15:00.000Z
# 1075  1.184452190  2021-06-18T18:00:00.000Z  2021-06-18T18:00:00.000Z
# 1326  1.184451737  2021-06-18T15:00:00.000Z  2021-06-18T15:00:00.000Z
#
#                   suspend_time                 open_date  \
# 149   2021-06-18T18:45:00.000Z  2021-06-18T18:45:00.000Z
# 1041  2021-06-18T19:15:00.000Z  2021-06-18T19:15:00.000Z
# 1053  2021-06-18T19:15:00.000Z  2021-06-18T19:15:00.000Z
# 1075  2021-06-18T18:00:00.000Z  2021-06-18T18:00:00.000Z
# 1326  2021-06-18T15:00:00.000Z  2021-06-18T15:00:00.000Z
#
#               api_call_time_utc  minutes_to_event  event_id venue  \
# 149  2021-06-18 10:39:25.527148        485.566667  30617284  None
# 1041 2021-06-18 10:39:25.527148        515.566667  30616138  None
# 1053 2021-06-18 10:39:25.527148        515.566667  30616138  None
# 1075 2021-06-18 10:39:25.527148        440.566667  30616203  None
# 1326 2021-06-18 10:39:25.527148        260.566667  30616114  None
#
#                        event_name competition_id           competition_name  \
# 149       Galway Utd v Cabinteely       12005855           Irish Division 1
# 1041        Afturelding v Selfoss       12010570          Icelandic 1 Deild
# 1053        Afturelding v Selfoss       12010570          Icelandic 1 Deild
# 1075            Thor v Kordrengir       12010570          Icelandic 1 Deild
# 1326  Slutsk v Shakhter Soligorsk       12149617  Belarusian Premier League
#
#      race_type    market_name    market_type event_type_id betting_type  \
# 149       None  Correct Score  CORRECT_SCORE             1         ODDS
# 1041      None  Correct Score  CORRECT_SCORE             1         ODDS
# 1053      None     Match Odds     MATCH_ODDS             1         ODDS
# 1075      None  Correct Score  CORRECT_SCORE             1         ODDS
# 1326      None  Correct Score  CORRECT_SCORE             1         ODDS
#
#      country_code timezone  bsp_market  in_play_enabled  persistence_enabled  \
# 149            IE      GMT       False             True                 True
# 1041           IS      GMT       False             True                 True
# 1053           IS      GMT       False             True                 True
# 1075           IS      GMT       False             True                 True
# 1326           BY      GMT       False             True                 True
#
#       market_base_rate            regulator  discount_allowed  \
# 149                5.0  GIBRALTAR REGULATOR             False
# 1041               5.0  GIBRALTAR REGULATOR             False
# 1053               5.0  GIBRALTAR REGULATOR             False
# 1075               5.0  GIBRALTAR REGULATOR             False
# 1326               5.0  GIBRALTAR REGULATOR             False
#
#       number_of_winners  number_of_runners  number_of_active_runners  \
# 149                   1                 19                        19
# 1041                  1                 19                        19
# 1053                  1                  3                         3
# 1075                  1                 19                        19
# 1326                  1                 19                        19
#
#                last_match_time  total_matched_market  total_available  \
# 149   2021-06-18T10:33:15.656Z                 25.63          7164.37
# 1041  2021-06-18T10:19:23.090Z                  9.12          8806.45
# 1053  2021-06-18T10:28:06.373Z                336.36          3617.02
# 1075  2021-06-18T10:36:51.746Z                 45.62          8690.49
# 1326  2021-06-18T10:36:47.957Z                118.25        156494.83
#
#       cross_matching  runners_voidable     version  is_market_data_delayed  \
# 149             True             False  3872185602                    True
# 1041            True             False  3872209812                    True
# 1053            True             False  3871032117                    True
# 1075            True             False  3872063307                    True
# 1326            True             False  3871720428                    True
#
#      market_status  bet_delay  bsp_reconciled  complete  inplay  runner_id  \
# 149           OPEN          0           False      True   False         12
# 1041          OPEN          0           False      True   False         11
# 1053          OPEN          0           False      True   False    3968885
# 1075          OPEN          0           False      True   False         12
# 1326          OPEN          0           False      True   False          7
#
#       runner_name  sort_priority  handicap  status   ltp  \
# 149         3 - 2             15       0.0  ACTIVE   NaN
# 1041        3 - 1             14       0.0  ACTIVE   NaN
# 1053  Afturelding              1       0.0  ACTIVE   2.9
# 1075        3 - 2             15       0.0  ACTIVE   NaN
# 1326        2 - 2             11       0.0  ACTIVE  30.0
#
#       total_matched_runner  back_price_1  back_price_2  back_price_3  \
# 149                    0.0         28.00          25.0         22.00
# 1041                   0.0         21.00          19.5         18.00
# 1053                   0.0          2.84           2.8          2.78
# 1075                   0.0         22.00          18.5          8.60
# 1326                   0.0         27.00          26.0         11.00
#
#       back_size_1  back_size_2  back_size_3  lay_price_1  lay_price_2  \
# 149         12.89        11.27        10.00        36.00         38.0
# 1041        13.31        15.03        10.00        27.00         30.0
# 1053        20.00        63.19       133.65         3.05          3.1
# 1075        10.27        10.00        11.83        27.00         29.0
# 1326        30.35        15.93        13.22        32.00         36.0
#
#       lay_price_3  lay_size_1  lay_size_2  lay_size_3 runner_name_general  \
# 149           NaN       10.19        5.35         NaN               3 - 2
# 1041          NaN       12.91        2.00         NaN               3 - 1
# 1053         3.15       79.35       21.72      157.77                Home
# 1075          NaN       10.29        7.54         NaN               3 - 2
# 1326          NaN       21.75        7.47         NaN               2 - 2
#
#             market_runner  input_odds      pred  pred_odds  bet  \
# 149   CORRECT_SCORE 3 - 2       28.00  0.056185  17.798305    1
# 1041  CORRECT_SCORE 3 - 1       21.00  0.063582  15.727799    1
# 1053      MATCH_ODDS Home        2.84  0.471202   2.122232    1
# 1075  CORRECT_SCORE 3 - 2       22.00  0.060071  16.647056    1
# 1326  CORRECT_SCORE 2 - 2       27.00  0.056588  17.671732    1
#
#       correct_score_overround  match_odds_overround  over_under_overround
# 149                  0.947813              1.028968              5.322000
# 1041                 0.867085              1.014168              5.549701
# 1053                 0.867085              1.014168              5.549701
# 1075                 0.886632              1.025194              5.352799
# 1326                 0.975346              1.021523              5.326977

# %%
max_bet = 2

for i in back_bets.index:
    market_id = str(back_bets.at[i, 'market_id'])
    selection_id = str(back_bets.at[i, 'runner_id'])
    available = back_bets.at[i, 'back_size_1']
    bet_size = str(min(available, max_bet))
    price = str(back_bets.at[i, 'back_price_1'])
    min_fill_size = str(2)
    market_version = str(back_bets.at[i, 'version'])
    
    try:
        order_request = '{"jsonrpc": "2.0", "method": "SportsAPING/v1.0/placeOrders",\
                    "params": {"marketId":"' + market_id + '","instructions":[\
                    {"selectionId":"' + selection_id + '","handicap":"0","side":"BACK","orderType":"LIMIT",\
                    "limitOrder":{"size":"' + bet_size + '","price":"' + price + '","persistenceType":"LAPSE",\
                    "timeInForce":"FILL_OR_KILL", "minFillSize":"' + min_fill_size + '"}}], "marketVersion":{"version":"' + market_version + '"}}, "id": 1}'
        request = requests.post(bet_url, data=order_request.encode('utf-8'), headers=headers)
        order_result = request.json()['result']
        order_results.append(order_result)
    except:
        order_fails.append([market_id, selection_id, available, bet_size, price, min_fill_size, market_version])

# %%
order_results_df = []
for o in order_results:
    order_results_df.append(parse_order_result(o))
order_results_df = pd.DataFrame(order_results_df, columns=order_cols)

order_fails_df = pd.DataFrame(order_fails, columns=['market_id', 'selection_id', 'available', 'bet_size', 'price', 'min_fill_size', 'market_version'])

# %%
order_results_df
# Out:
#     status    market_id  selection_id  handicap  size  price time_in_force  \
# 0  SUCCESS  1.184467158            12       0.0   2.0  28.00  FILL_OR_KILL
# 1  SUCCESS  1.184452390            11       0.0   2.0  21.00  FILL_OR_KILL
# 2  SUCCESS  1.184452381       3968885       0.0   2.0   2.84  FILL_OR_KILL
# 3  SUCCESS  1.184452190            12       0.0   2.0  22.00  FILL_OR_KILL
# 4  SUCCESS  1.184451737             7       0.0   2.0  27.00  FILL_OR_KILL
#
#    min_fill_size order_type  side error_code        bet_id  \
# 0            2.0      LIMIT  BACK       None  236151012208
# 1            2.0      LIMIT  BACK       None  236151012610
# 2            2.0      LIMIT  BACK       None  236151012783
# 3            2.0      LIMIT  BACK       None  236151013293
# 4            2.0      LIMIT  BACK       None  236151013918
#
#                 placed_date  average_price_matched  size_matched  \
# 0  2021-06-18T10:41:29.000Z                  29.00           2.0
# 1  2021-06-18T10:41:30.000Z                  22.00           2.0
# 2  2021-06-18T10:41:30.000Z                   2.84           2.0
# 3  2021-06-18T10:41:30.000Z                  24.00           2.0
# 4  2021-06-18T10:41:31.000Z                  28.00           2.0
#
#          order_status
# 0  EXECUTION_COMPLETE
# 1  EXECUTION_COMPLETE
# 2  EXECUTION_COMPLETE
# 3  EXECUTION_COMPLETE
# 4  EXECUTION_COMPLETE

# %% [markdown]
# #### Send all data to db

# %%
connect_string = 'mysql+pymysql://root:'+dbpw+'@localhost/betfair'
sql_engine = sqlalchemy.create_engine(connect_string)

# %%
# drop pred bet cols in case confusing later on
pred_df = pred_df.drop(columns=[o.replace(' - ltp', ' - bet') for o in select_markets])

# %%
# really need to replace this with actual columns selections
pred_df = pred_df[[c for c in pred_df.columns if 'Atletico' not in c]]
pred_df = pred_df[[c for c in pred_df.columns if 'Fujieda' not in c]]
pred_df = pred_df[[c for c in pred_df.columns if 'CD MAIPU' not in c]]
pred_df = pred_df[[c for c in pred_df.columns if 'San Martin de San Juan' not in c]]

# %%
pred_df.to_sql(name='football_predictions_live', con=sql_engine, schema='betfair', if_exists='append', index=False)
output_df.to_sql(name='football_output_live', con=sql_engine, schema='betfair', if_exists='append', index=False)
order_results_df.to_sql(name='football_order_results_live', con=sql_engine, schema='betfair', if_exists='append', index=False)
order_fails_df.to_sql(name='football_order_fails_live', con=sql_engine, schema='betfair', if_exists='append', index=False)

# %% [markdown]
# #### Other thoughts for productionizing:
# * Make separate classes
# * Store models more intelligently, perhaps as 1 dict and also with supplemental info like features, default values etc (although is some of this already in model artifact?)
# * Probably need more checks and controls
